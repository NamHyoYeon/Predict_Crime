# %% [markdown]
# # **XG BOOST에 필요한 라이브러리 호출**

# %%
from sklearn.datasets import load_boston
import xgboost
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import explained_variance_score
from sklearn.metrics import mean_squared_error

# %%
import warnings
warnings.filterwarnings(action="ignore")

# %% [markdown]
# # **데이터 불러오기**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/drive/MyDrive/빅예분3조/Data/prescale/KPU_DATA_MERGE3.csv', encoding='euc-kr')

# %%
df
# Out:
#       Unnamed: 0  ACPT_YM  PLCST_NM  RPRT_CASCNT_WHOL  OCRN_DOTW_SNDD  \
# 0              0   201901   서울중랑경찰서                37               6
# 1              1   201901   서울노원경찰서                62               6
# 2              2   201901  부산해운대경찰서                37               3
# 3              3   201901   울산중부경찰서                56               7
# 4              4   201901   대구성서경찰서                24               6
# ...          ...      ...       ...               ...             ...
# 8522        8522   202112   인천논현경찰서                39               8
# 8523        8523   202112   부산중부경찰서                19               0
# 8524        8524   202112   대전서부경찰서                20               4
# 8525        8525   202112     함안경찰서                 1               0
# 8526        8526   202112     상주경찰서                 1               0
#
#       OCRN_DOTW_MON  OCRN_DOTW_TUE  OCRN_DOTW_WED  OCRN_DOTW_THU  \
# 0                 8              4              5              6
# 1                 6             13              7             16
# 2                 5              7              6              3
# 3                 6              9              8              4
# 4                 1              5              0              5
# ...             ...            ...            ...            ...
# 8522              1              7              1              4
# 8523              1              0              2              6
# 8524              3              1              4              3
# 8525              1              0              0              0
# 8526              1              0              0              0
#
#       OCRN_DOTW_FRI  ...  CHILD_OCRN_DOTW_SAT  CHILD_TIZN_1  CHILD_TIZN_2  \
# 0                 3  ...                  403          1617           630
# 1                 5  ...                  468          1776           770
# 2                 8  ...                  300          1104           482
# 3                11  ...                  387          1396           649
# 4                 2  ...                  212           862           362
# ...             ...  ...                  ...           ...           ...
# 8522              4  ...                  274          1010           516
# 8523              4  ...                   30           103            36
# 8524              2  ...                  247          1029           473
# 8525              0  ...                   33            87            58
# 8526              0  ...                   49           183            82
#
#       CHILD_TIZN_3  CHILD_TIZN_4                         ADDR     SI   SGG  \
# 0              181            83  서울특별시 중랑구 신내역로3길 40-10(신내동)  서울특별시   중랑구
# 1              253           108       서울특별시 노원구 노원로 283(하계동)  서울특별시   노원구
# 2              142            95   부산광역시 해운대구 달맞이길62번길 42(중동)  부산광역시  해운대구
# 3              173            72        울산광역시 중구 번영로 620(남외동)  울산광역시    중구
# 4              125            54  대구광역시 달서구 달구벌대로259길 15(이곡동)  대구광역시   달서구
# ...            ...           ...                          ...    ...   ...
# 8522           139            60          인천광역시 남동구 논현고잔로 239  인천광역시   남동구
# 8523             5             6     부산광역시 중구 중앙대로 105(대창동1가)  부산광역시    중구
# 8524           133            69        대전광역시 서구 복수서로 47(복수동)  대전광역시    서구
# 8525            13             4          경상남도 함안군 가야읍 가야로 85   경상남도   함안군
# 8526            16            12        경상북도 상주시 왕산로 119(남성동)   경상북도   상주시
#
#             LON         LAT
# 0     37.618254  127.104468
# 1     37.641975  127.070799
# 2     35.158240  129.171762
# 3     35.569829  129.349216
# 4     35.853219  128.508774
# ...         ...         ...
# 8522  37.404077  126.715039
# 8523  35.107421  129.035925
# 8524  36.309045  127.373459
# 8525  35.279147  128.410910
# 8526  36.410939  128.161917
#
# [8527 rows x 48 columns]

# %% [markdown]
# # **XG BOOST에 필요한 변수 생성**
#
# X_train, X_test, y_train, y_test = train_test_split(df.data, df.target ,test_size=0.2)
#
# xgb_model = xgboost.XGBRegressor(n_estimators=100, learning_rate=0.08, gamma=0, subsample=0.75,colsample_bytree=1, max_depth=7)

# %%
print(df.keys())
# Out:
# Index(['Unnamed: 0', 'ACPT_YM', 'PLCST_NM', 'RPRT_CASCNT_WHOL',
#        'OCRN_DOTW_SNDD', 'OCRN_DOTW_MON', 'OCRN_DOTW_TUE', 'OCRN_DOTW_WED',
#        'OCRN_DOTW_THU', 'OCRN_DOTW_FRI', 'OCRN_DOTW_SAT', 'TIZN_1', 'TIZN_2',
#        'TIZN_3', 'TIZN_4', 'SCHOOL_RPRT_CASCNT_WHOL', 'SCHOOL_OCRN_DOTW_SNDD',
#        'SCHOOL_OCRN_DOTW_MON', 'SCHOOL_OCRN_DOTW_TUE', 'SCHOOL_OCRN_DOTW_WED',
#        'SCHOOL_OCRN_DOTW_THU', 'SCHOOL_OCRN_DOTW_FRI', 'SCHOOL_OCRN_DOTW_SAT',
#        'SCHOOL_TIZN_1', 'SCHOOL_TIZN_2', 'SCHOOL_TIZN_3', 'SCHOOL_TIZN_4',
#        'STRD_YR', 'CHILD_RPRT_CASCNT_WHOL', 'CHILD_DSTVC_RPRT_CNT',
#        'CHILD_CHLAB_ASMP', 'CHILD_CHLAB_ETC', 'CHILD_OCRN_DOTW_SNDD',
#        'CHILD_OCRN_DOTW_MON', 'CHILD_OCRN_DOTW_TUE', 'CHILD_OCRN_DOTW_WED',
#        'CHILD_OCRN_DOTW_THU', 'CHILD_OCRN_DOTW_FRI', 'CHILD_OCRN_DOTW_SAT',
#        'CHILD_TIZN_1', 'CHILD_TIZN_2', 'CHILD_TIZN_3', 'CHILD_TIZN_4', 'ADDR',
#        'SI', 'SGG', 'LON', 'LAT'],
#       dtype='object')

# %%
df.plcst = df['PLCST_NM'].unique()
df.plcst
print(df.plcst)
print(len(df.plcst))
# Out:
# ['서울중랑경찰서' '서울노원경찰서' '부산해운대경찰서' '울산중부경찰서' '대구성서경찰서' '전주완산경찰서' '대전중부경찰서'
#  '삼척경찰서' '괴산경찰서' '서산경찰서' '금산경찰서' '영주경찰서' '남양주경찰서' '동두천경찰서' '화성동탄경찰서'
#  '제주자치경찰단' '천안동남경찰서' '부천소사경찰서' '이천경찰서' 'ETC' '서울방배경찰서' '동해경찰서' '진천경찰서'
#  '마산중부경찰서' '남해경찰서' '무주경찰서' '창원중부경찰서' '서대문경찰서' '서울용산경찰서' '서울성북경찰서' '성동경찰서'
#  '서울강서경찰서' '부산동부경찰서' '대구북부경찰서' '인천서부경찰서' '연수경찰서' '울산남부경찰서' '동부경찰서'
#  '서울광진경찰서' '울산울주경찰서' '광주북부경찰서' '인천삼산경찰서' '속초경찰서' '포항남부경찰서' '진해경찰서' '정읍경찰서'
#  '양주경찰서' '포천경찰서' '가평경찰서' '일산서부경찰서' '수원중부경찰서' '안양동안경찰서' '군포경찰서' '성남수정경찰서'
#  '의왕경찰서' '하남경찰서' '여주경찰서' '횡성경찰서' '고흥경찰서' '담양경찰서' '서울수서경찰서' '인천중부경찰서'
#  '전주덕진경찰서' '대전동부경찰서' '제주서부경찰서' '김해중부경찰서' '태백경찰서' '양구경찰서' '충주경찰서' '서천경찰서'
#  '여수경찰서' '서귀포경찰서' '구리경찰서' '태안경찰서' '오산경찰서' '천안서북경찰서' '대구강북경찰서' '대전유성경찰서'
#  '수원남부경찰서' '안양만안경찰서' '광명경찰서' '안산단원경찰서' '용인동부경찰서' '김포경찰서' '서울서초경찰서'
#  '부산사상경찰서' '부산연제경찰서' '광주동부경찰서' '강진경찰서' '서울남대문경찰서' '옥천경찰서' '단양경찰서' '의성경찰서'
#  '영등포경찰서' '부산동래경찰서' '부산사하경찰서' '광주남부경찰서' '대전대덕경찰서' '강릉경찰서' '당진경찰서' '진주경찰서'
#  '통영경찰서' '거제경찰서' '함양경찰서' '광양경찰서' '일산동부경찰서' '기장경찰서' '세종경찰서' '용인서부경찰서'
#  '익산경찰서' '서울혜화경찰서' '홍천경찰서' '영월경찰서' '문경경찰서' '봉화경찰서' '합천경찰서' '진안경찰서' '고령경찰서'
#  '철원경찰서' '서울서부경찰서' '서울양천경찰서' '서울송파경찰서' '서울도봉경찰서' '부산북부경찰서' '대구동부경찰서'
#  '대구달성경찰서' '인천남동경찰서' '청주흥덕경찰서' '김해서부경찰서' '부산진경찰서' '원주경찰서' '논산경찰서' '경산경찰서'
#  '거창경찰서' '안산상록경찰서' '시흥경찰서' '광주경찰서' '안성경찰서' '의정부경찰서' '부산영도경찰서' '홍성경찰서'
#  '부안경찰서' '연천경찰서' '화성서부경찰서' '대구남부경찰서' '예산경찰서' '서울마포경찰서' '서울구로경찰서' '은평경찰서'
#  '대구달서경찰서' '금천경찰서' '서울동대문경찰서' '광주광산경찰서' '보령경찰서' '아산경찰서' '경주경찰서' '마산동부경찰서'
#  '사천경찰서' '군산경찰서' '완주경찰서' '순천경찰서' '평택경찰서' '양평경찰서' '부산서부경찰서' '부여경찰서' '청양경찰서'
#  '나주경찰서' '해남경찰서' '고성경찰서' '김제경찰서' '영암경찰서' '창원서부경찰서' '서울종암경찰서' '부산남부경찰서'
#  '대구중부경찰서' '인천부평경찰서' '인천계양경찰서' '서울강북경찰서' '광주서부경찰서' '공주경찰서' '칠곡경찰서' '창녕경찰서'
#  '목포경찰서' '구례경찰서' '화순경찰서' '파주경찰서' '청주청원경찰서' '성남중원경찰서' '분당경찰서' '부천오정경찰서'
#  '고양경찰서' '영광경찰서' '제천경찰서' '음성경찰서' '장흥경찰서' '보성경찰서' '김천경찰서' '서울중부경찰서'
#  '서울관악경찰서' '서울강동경찰서' '부산중부경찰서' '부산금정경찰서' '대구서부경찰서' '대구수성경찰서' '서울동작경찰서'
#  '대전서부경찰서' '대전둔산경찰서' '제주경찰청' '춘천경찰서' '포항북부경찰서' '구미경찰서' '상주경찰서' '양산경찰서'
#  '함안경찰서' '남원경찰서' '무안경찰서' '인천논현경찰서' '인천미추홀경찰서' '청주상당경찰서' '수원서부경찰서'
#  '부천원미경찰서' '강남경찰서' '제주동부경찰서' '안동경찰서' '평창경찰서' '영천경찰서' '장수경찰서' '밀양경찰서'
#  '보은경찰서' '영동경찰서' '하동경찰서' '정선경찰서' '예천경찰서' '청도경찰서' '인천강화경찰서' '장성경찰서' '울진경찰서'
#  '진도경찰서' '화천경찰서' '부산강서경찰서' '서울종로경찰서' '영덕경찰서' '완도경찰서' '함평경찰서' '서울경찰청'
#  '고창경찰서' '청송경찰서' '인제경찰서' '과천경찰서' '경비교통과' '산청경찰서' '군위경찰서' '충청남도경찰청' '교통과'
#  '광주경찰청' '부산경찰청' '성주경찰서' '충청북도경찰청' '경기북부경찰청' '경기남부경찰청' '순창경찰서' '인천경찰청'
#  '전라남도경찰청' '인천국제공항경찰단' '의령경찰서' '강원경찰청' '대구경찰청' '임실경찰서' '경남경찰청' '전북경찰청'
#  '곡성경찰서' '대전경찰청' '울릉경찰서' '영양경찰서' '경찰청']
# 275

# %%
df0 = df.set_index('PLCST_NM')

# %%
df0
# Out:
#           Unnamed: 0  ACPT_YM  RPRT_CASCNT_WHOL  OCRN_DOTW_SNDD  \
# PLCST_NM
# 서울중랑경찰서            0   201901                37               6
# 서울노원경찰서            1   201901                62               6
# 부산해운대경찰서           2   201901                37               3
# 울산중부경찰서            3   201901                56               7
# 대구성서경찰서            4   201901                24               6
# ...              ...      ...               ...             ...
# 인천논현경찰서         8522   202112                39               8
# 부산중부경찰서         8523   202112                19               0
# 대전서부경찰서         8524   202112                20               4
# 함안경찰서           8525   202112                 1               0
# 상주경찰서           8526   202112                 1               0
#
#           OCRN_DOTW_MON  OCRN_DOTW_TUE  OCRN_DOTW_WED  OCRN_DOTW_THU  \
# PLCST_NM
# 서울중랑경찰서               8              4              5              6
# 서울노원경찰서               6             13              7             16
# 부산해운대경찰서              5              7              6              3
# 울산중부경찰서               6              9              8              4
# 대구성서경찰서               1              5              0              5
# ...                 ...            ...            ...            ...
# 인천논현경찰서               1              7              1              4
# 부산중부경찰서               1              0              2              6
# 대전서부경찰서               3              1              4              3
# 함안경찰서                 1              0              0              0
# 상주경찰서                 1              0              0              0
#
#           OCRN_DOTW_FRI  OCRN_DOTW_SAT  ...  CHILD_OCRN_DOTW_SAT  \
# PLCST_NM                                ...
# 서울중랑경찰서               3              5  ...                  403
# 서울노원경찰서               5              9  ...                  468
# 부산해운대경찰서              8              5  ...                  300
# 울산중부경찰서              11             11  ...                  387
# 대구성서경찰서               2              5  ...                  212
# ...                 ...            ...  ...                  ...
# 인천논현경찰서               4             14  ...                  274
# 부산중부경찰서               4              6  ...                   30
# 대전서부경찰서               2              3  ...                  247
# 함안경찰서                 0              0  ...                   33
# 상주경찰서                 0              0  ...                   49
#
#           CHILD_TIZN_1  CHILD_TIZN_2  CHILD_TIZN_3  CHILD_TIZN_4  \
# PLCST_NM
# 서울중랑경찰서           1617           630           181            83
# 서울노원경찰서           1776           770           253           108
# 부산해운대경찰서          1104           482           142            95
# 울산중부경찰서           1396           649           173            72
# 대구성서경찰서            862           362           125            54
# ...                ...           ...           ...           ...
# 인천논현경찰서           1010           516           139            60
# 부산중부경찰서            103            36             5             6
# 대전서부경찰서           1029           473           133            69
# 함안경찰서               87            58            13             4
# 상주경찰서              183            82            16            12
#
#                                  ADDR     SI   SGG        LON         LAT
# PLCST_NM
# 서울중랑경찰서   서울특별시 중랑구 신내역로3길 40-10(신내동)  서울특별시   중랑구  37.618254  127.104468
# 서울노원경찰서        서울특별시 노원구 노원로 283(하계동)  서울특별시   노원구  37.641975  127.070799
# 부산해운대경찰서   부산광역시 해운대구 달맞이길62번길 42(중동)  부산광역시  해운대구  35.158240  129.171762
# 울산중부경찰서         울산광역시 중구 번영로 620(남외동)  울산광역시    중구  35.569829  129.349216
# 대구성서경찰서   대구광역시 달서구 달구벌대로259길 15(이곡동)  대구광역시   달서구  35.853219  128.508774
# ...                               ...    ...   ...        ...         ...
# 인천논현경찰서           인천광역시 남동구 논현고잔로 239  인천광역시   남동구  37.404077  126.715039
# 부산중부경찰서      부산광역시 중구 중앙대로 105(대창동1가)  부산광역시    중구  35.107421  129.035925
# 대전서부경찰서         대전광역시 서구 복수서로 47(복수동)  대전광역시    서구  36.309045  127.373459
# 함안경찰서             경상남도 함안군 가야읍 가야로 85   경상남도   함안군  35.279147  128.410910
# 상주경찰서           경상북도 상주시 왕산로 119(남성동)   경상북도   상주시  36.410939  128.161917
#
# [8527 rows x 47 columns]

# %%
df.plcst[0]
# Out:
# '서울중랑경찰서'

# %%
df0.loc[df.plcst[0],:]
# Out:
#           Unnamed: 0  ACPT_YM  RPRT_CASCNT_WHOL  OCRN_DOTW_SNDD  \
# PLCST_NM
# 서울중랑경찰서            0   201901                37               6
# 서울중랑경찰서          233   201902                56               6
# 서울중랑경찰서          466   201903               125              22
# 서울중랑경찰서          708   201904               102              12
# 서울중랑경찰서          939   201905               174              16
# 서울중랑경찰서         1189   201906               224              48
# 서울중랑경찰서         1435   201907               130              23
# 서울중랑경찰서         1682   201908               163              22
# 서울중랑경찰서         1934   201909               199              55
# 서울중랑경찰서         2175   201910               191              28
# 서울중랑경찰서         2414   201911               121               6
# 서울중랑경찰서         2652   201912                79              16
# 서울중랑경찰서         2888   202001                91              11
# 서울중랑경찰서         3120   202002                89              15
# 서울중랑경찰서         3358   202003                94              12
# 서울중랑경찰서         3589   202004                92               9
# 서울중랑경찰서         3949   202005               144              29
# 서울중랑경찰서         4190   202006               130              14
# 서울중랑경찰서         4434   202007               114              16
# 서울중랑경찰서         4671   202008                93               9
# 서울중랑경찰서         4909   202009               177              26
# 서울중랑경찰서         5153   202010               192              24
# 서울중랑경찰서         5272   202011               118              13
# 서울중랑경찰서         5503   202012                79               9
# 서울중랑경찰서         5842   202101                50               5
# 서울중랑경찰서         6066   202102                57               9
# 서울중랑경찰서         6294   202103               120              16
# 서울중랑경찰서         6527   202104               123              20
# 서울중랑경찰서         6767   202105               141              19
# 서울중랑경찰서         7004   202106               175              26
# 서울중랑경찰서         7245   202107               120               9
# 서울중랑경찰서         7480   202108               122              18
# 서울중랑경찰서         7717   202109               198              22
# 서울중랑경찰서         7962   202110               200              41
# 서울중랑경찰서         8191   202111               124              15
# 서울중랑경찰서         8422   202112                85              11
#
#           OCRN_DOTW_MON  OCRN_DOTW_TUE  OCRN_DOTW_WED  OCRN_DOTW_THU  \
# PLCST_NM
# 서울중랑경찰서               8              4              5              6
# 서울중랑경찰서               8              2              7             11
# 서울중랑경찰서              23             17             11             14
# 서울중랑경찰서              13             18             12             16
# 서울중랑경찰서              14             24             33             26
# 서울중랑경찰서              28             24             21             21
# 서울중랑경찰서              19             12             26             17
# 서울중랑경찰서              18             12             24             19
# 서울중랑경찰서              28             22             28             21
# 서울중랑경찰서              17             32             24             30
# 서울중랑경찰서              14             18             13             15
# 서울중랑경찰서               9             13             13              6
# 서울중랑경찰서               7             14             18             18
# 서울중랑경찰서              13             11              4              9
# 서울중랑경찰서              13             19             12             11
# 서울중랑경찰서              22              8             14             15
# 서울중랑경찰서              23             12             15             10
# 서울중랑경찰서              20             27             11             24
# 서울중랑경찰서              13             18             18             10
# 서울중랑경찰서              16             13             14             15
# 서울중랑경찰서              21             24             24             23
# 서울중랑경찰서              24             28             19             23
# 서울중랑경찰서              26             11             17             12
# 서울중랑경찰서               9              7              9             17
# 서울중랑경찰서               5              8             10              7
# 서울중랑경찰서               4              2              7              7
# 서울중랑경찰서               7             24             18             18
# 서울중랑경찰서              13             16             14             27
# 서울중랑경찰서              19             15             21             17
# 서울중랑경찰서              22             34             23             16
# 서울중랑경찰서              12             17             14             20
# 서울중랑경찰서              18             19             12              8
# 서울중랑경찰서              19             21             34             39
# 서울중랑경찰서              13             19             23             31
# 서울중랑경찰서               9             18             17             18
# 서울중랑경찰서               5             14             16             13
#
#           OCRN_DOTW_FRI  OCRN_DOTW_SAT  ...  CHILD_OCRN_DOTW_SAT  \
# PLCST_NM                                ...
# 서울중랑경찰서               3              5  ...                  403
# 서울중랑경찰서               6             16  ...                  403
# 서울중랑경찰서              17             21  ...                  403
# 서울중랑경찰서              18             13  ...                  403
# 서울중랑경찰서              31             30  ...                  403
# 서울중랑경찰서              31             51  ...                  403
# 서울중랑경찰서              15             18  ...                  403
# 서울중랑경찰서              37             31  ...                  403
# 서울중랑경찰서              21             24  ...                  403
# 서울중랑경찰서              37             23  ...                  403
# 서울중랑경찰서              30             25  ...                  403
# 서울중랑경찰서              11             11  ...                  403
# 서울중랑경찰서              11             12  ...                  101
# 서울중랑경찰서              18             19  ...                  101
# 서울중랑경찰서              17             10  ...                  101
# 서울중랑경찰서              11             13  ...                  101
# 서울중랑경찰서              27             28  ...                  101
# 서울중랑경찰서              17             17  ...                  101
# 서울중랑경찰서              24             15  ...                  101
# 서울중랑경찰서              17              9  ...                  101
# 서울중랑경찰서              21             38  ...                  101
# 서울중랑경찰서              38             36  ...                  101
# 서울중랑경찰서              23             16  ...                  101
# 서울중랑경찰서              17             11  ...                  101
# 서울중랑경찰서               8              7  ...                  366
# 서울중랑경찰서              16             12  ...                  366
# 서울중랑경찰서              19             18  ...                  366
# 서울중랑경찰서              18             15  ...                  366
# 서울중랑경찰서              24             26  ...                  366
# 서울중랑경찰서              24             30  ...                  366
# 서울중랑경찰서              19             29  ...                  366
# 서울중랑경찰서              33             14  ...                  366
# 서울중랑경찰서              37             26  ...                  366
# 서울중랑경찰서              36             37  ...                  366
# 서울중랑경찰서              21             26  ...                  366
# 서울중랑경찰서              19              7  ...                  366
#
#           CHILD_TIZN_1  CHILD_TIZN_2  CHILD_TIZN_3  CHILD_TIZN_4  \
# PLCST_NM
# 서울중랑경찰서           1617           630           181            83
# 서울중랑경찰서           1617           630           181            83
# 서울중랑경찰서           1617           630           181            83
# 서울중랑경찰서           1617           630           181            83
# 서울중랑경찰서           1617           630           181            83
# 서울중랑경찰서           1617           630           181            83
# 서울중랑경찰서           1617           630           181            83
# 서울중랑경찰서           1617           630           181            83
# 서울중랑경찰서           1617           630           181            83
# 서울중랑경찰서           1617           630           181            83
# 서울중랑경찰서           1617           630           181            83
# 서울중랑경찰서           1617           630           181            83
# 서울중랑경찰서            406           220            47            15
# 서울중랑경찰서            406           220            47            15
# 서울중랑경찰서            406           220            47            15
# 서울중랑경찰서            406           220            47            15
# 서울중랑경찰서            406           220            47            15
# 서울중랑경찰서            406           220            47            15
# 서울중랑경찰서            406           220            47            15
# 서울중랑경찰서            406           220            47            15
# 서울중랑경찰서            406           220            47            15
# 서울중랑경찰서            406           220            47            15
# 서울중랑경찰서            406           220            47            15
# 서울중랑경찰서            406           220            47            15
# 서울중랑경찰서           1411           628           154            72
# 서울중랑경찰서           1411           628           154            72
# 서울중랑경찰서           1411           628           154            72
# 서울중랑경찰서           1411           628           154            72
# 서울중랑경찰서           1411           628           154            72
# 서울중랑경찰서           1411           628           154            72
# 서울중랑경찰서           1411           628           154            72
# 서울중랑경찰서           1411           628           154            72
# 서울중랑경찰서           1411           628           154            72
# 서울중랑경찰서           1411           628           154            72
# 서울중랑경찰서           1411           628           154            72
# 서울중랑경찰서           1411           628           154            72
#
#                                  ADDR     SI  SGG        LON         LAT
# PLCST_NM
# 서울중랑경찰서   서울특별시 중랑구 신내역로3길 40-10(신내동)  서울특별시  중랑구  37.618254  127.104468
# 서울중랑경찰서   서울특별시 중랑구 신내역로3길 40-10(신내동)  서울특별시  중랑구  37.618254  127.104468
# 서울중랑경찰서   서울특별시 중랑구 신내역로3길 40-10(신내동)  서울특별시  중랑구  37.618254  127.104468
# 서울중랑경찰서   서울특별시 중랑구 신내역로3길 40-10(신내동)  서울특별시  중랑구  37.618254  127.104468
# 서울중랑경찰서   서울특별시 중랑구 신내역로3길 40-10(신내동)  서울특별시  중랑구  37.618254  127.104468
# 서울중랑경찰서   서울특별시 중랑구 신내역로3길 40-10(신내동)  서울특별시  중랑구  37.618254  127.104468
# 서울중랑경찰서   서울특별시 중랑구 신내역로3길 40-10(신내동)  서울특별시  중랑구  37.618254  127.104468
# 서울중랑경찰서   서울특별시 중랑구 신내역로3길 40-10(신내동)  서울특별시  중랑구  37.618254  127.104468
# 서울중랑경찰서   서울특별시 중랑구 신내역로3길 40-10(신내동)  서울특별시  중랑구  37.618254  127.104468
# 서울중랑경찰서   서울특별시 중랑구 신내역로3길 40-10(신내동)  서울특별시  중랑구  37.618254  127.104468
# 서울중랑경찰서   서울특별시 중랑구 신내역로3길 40-10(신내동)  서울특별시  중랑구  37.618254  127.104468
# 서울중랑경찰서   서울특별시 중랑구 신내역로3길 40-10(신내동)  서울특별시  중랑구  37.618254  127.104468
# 서울중랑경찰서   서울특별시 중랑구 신내역로3길 40-10(신내동)  서울특별시  중랑구  37.618254  127.104468
# 서울중랑경찰서   서울특별시 중랑구 신내역로3길 40-10(신내동)  서울특별시  중랑구  37.618254  127.104468
# 서울중랑경찰서   서울특별시 중랑구 신내역로3길 40-10(신내동)  서울특별시  중랑구  37.618254  127.104468
# 서울중랑경찰서   서울특별시 중랑구 신내역로3길 40-10(신내동)  서울특별시  중랑구  37.618254  127.104468
# 서울중랑경찰서   서울특별시 중랑구 신내역로3길 40-10(신내동)  서울특별시  중랑구  37.618254  127.104468
# 서울중랑경찰서   서울특별시 중랑구 신내역로3길 40-10(신내동)  서울특별시  중랑구  37.618254  127.104468
# 서울중랑경찰서   서울특별시 중랑구 신내역로3길 40-10(신내동)  서울특별시  중랑구  37.618254  127.104468
# 서울중랑경찰서   서울특별시 중랑구 신내역로3길 40-10(신내동)  서울특별시  중랑구  37.618254  127.104468
# 서울중랑경찰서   서울특별시 중랑구 신내역로3길 40-10(신내동)  서울특별시  중랑구  37.618254  127.104468
# 서울중랑경찰서   서울특별시 중랑구 신내역로3길 40-10(신내동)  서울특별시  중랑구  37.618254  127.104468
# 서울중랑경찰서   서울특별시 중랑구 신내역로3길 40-10(신내동)  서울특별시  중랑구  37.618254  127.104468
# 서울중랑경찰서   서울특별시 중랑구 신내역로3길 40-10(신내동)  서울특별시  중랑구  37.618254  127.104468
# 서울중랑경찰서   서울특별시 중랑구 신내역로3길 40-10(신내동)  서울특별시  중랑구  37.618254  127.104468
# 서울중랑경찰서   서울특별시 중랑구 신내역로3길 40-10(신내동)  서울특별시  중랑구  37.618254  127.104468
# 서울중랑경찰서   서울특별시 중랑구 신내역로3길 40-10(신내동)  서울특별시  중랑구  37.618254  127.104468
# 서울중랑경찰서   서울특별시 중랑구 신내역로3길 40-10(신내동)  서울특별시  중랑구  37.618254  127.104468
# 서울중랑경찰서   서울특별시 중랑구 신내역로3길 40-10(신내동)  서울특별시  중랑구  37.618254  127.104468
# 서울중랑경찰서   서울특별시 중랑구 신내역로3길 40-10(신내동)  서울특별시  중랑구  37.618254  127.104468
# 서울중랑경찰서   서울특별시 중랑구 신내역로3길 40-10(신내동)  서울특별시  중랑구  37.618254  127.104468
# 서울중랑경찰서   서울특별시 중랑구 신내역로3길 40-10(신내동)  서울특별시  중랑구  37.618254  127.104468
# 서울중랑경찰서   서울특별시 중랑구 신내역로3길 40-10(신내동)  서울특별시  중랑구  37.618254  127.104468
# 서울중랑경찰서   서울특별시 중랑구 신내역로3길 40-10(신내동)  서울특별시  중랑구  37.618254  127.104468
# 서울중랑경찰서   서울특별시 중랑구 신내역로3길 40-10(신내동)  서울특별시  중랑구  37.618254  127.104468
# 서울중랑경찰서   서울특별시 중랑구 신내역로3길 40-10(신내동)  서울특별시  중랑구  37.618254  127.104468
#
# [36 rows x 47 columns]

# %% [markdown]
# # **for문 이용하여 경찰서별 XG BOOST 모델 학습**

# %%
## 제주경찰청 데이터가 두개밖에 없어서 test size가 0.5 이하로 나와서 에러가 생기는 것 같다
## if len(df_i) < 3 이면 학습모델 실행하지 않고 preds_i = 0 찍고 넘어가는 것으로 개선

# %%
## 교통과 데이터는 하나 뿐이라 len(df0.loc[df.plcst[253],:]) 찍었을때 1이 아니라 컬럼갯수인 47이 출력됨.
## 고성경찰서 항목에서 이상한 점 발견
## 12개월씩 3년 데이터면 최대 36개 데이터가 나올 수 있는데 고성경찰서는 120개 조회
## if len(df_i) > 36 이면 이상치 데이터로 보고 학습모델 실행하지 않고 넘어가는 것으로 개선

# %%
df0.loc[df.plcst[253],:]
len(df0.loc[df.plcst[253],:])
# Out:
# 47

# %%
#  빈 리스트를 하나 만들어주고 반복문마다 결과를 추가
preds = []

# %%
for i in range(len(df.plcst)):
  print(i,".", df.plcst[i])
  df_i = df0.loc[df.plcst[i],:]
  if len(df_i) < 3:
    preds_i = [0]
    preds.append(preds_i)
    print("12월 예상 건수:", preds_i)
    continue
  if len(df_i) > 36:
    preds_i = [0]
    preds.append(preds_i)
    print("12월 예상 건수:", preds_i)
    continue
  df1 = df_i[df_i['ACPT_YM'] < 202112]
  df2 = df_i[df_i['ACPT_YM'] == 202112]
  df1.data = df1.drop(columns=['Unnamed: 0', 'OCRN_DOTW_TUE', 'ADDR', 'SI', 'SGG'])
  df2.data = df2.drop(columns=['Unnamed: 0', 'OCRN_DOTW_TUE', 'ADDR', 'SI', 'SGG' ])
  df1.target = pd.DataFrame(df1['OCRN_DOTW_TUE'])
  df2.target = pd.DataFrame(df2['OCRN_DOTW_TUE'])
  X_train, X_test, y_train, y_test = train_test_split(df1.data, df1.target ,test_size=0.2)
  xgb_model = xgboost.XGBRegressor(objective = 'reg:linear', n_estimators=100, learning_rate=0.08, gamma=0, subsample=0.75,colsample_bytree=1, max_depth=7)
  xgb_model.fit(X_train,y_train)
  pred_test = xgb_model.predict(X_test)
  preds_i = xgb_model.predict(df2.data)
  if preds_i < 0:
    preds_i = [0]
  preds.append(preds_i)
  print("12월 예상 건수:", preds_i)
  print("12월 실제 건수", df2.target['OCRN_DOTW_TUE'])
# Out:
# 0 . 서울중랑경찰서
# [13:15:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [7.608289]
# 12월 실제 건수 PLCST_NM
# 서울중랑경찰서    14
# Name: OCRN_DOTW_TUE, dtype: int64
# 1 . 서울노원경찰서
# [13:15:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [10.367917]
# 12월 실제 건수 PLCST_NM
# 서울노원경찰서    6
# Name: OCRN_DOTW_TUE, dtype: int64
# 2 . 부산해운대경찰서
# [13:15:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [6.271647]
# 12월 실제 건수 PLCST_NM
# 부산해운대경찰서    5
# Name: OCRN_DOTW_TUE, dtype: int64
# 3 . 울산중부경찰서
# [13:15:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [6.0548587]
# 12월 실제 건수 PLCST_NM
# 울산중부경찰서    2
# Name: OCRN_DOTW_TUE, dtype: int64
# 4 . 대구성서경찰서
# [13:15:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [3.012378]
# 12월 실제 건수 PLCST_NM
# 대구성서경찰서    8
# Name: OCRN_DOTW_TUE, dtype: int64
# 5 . 전주완산경찰서
# [13:15:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [4.066536]
# 12월 실제 건수 PLCST_NM
# 전주완산경찰서    6
# Name: OCRN_DOTW_TUE, dtype: int64
# 6 . 대전중부경찰서
# [13:15:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [4.802943]
# 12월 실제 건수 PLCST_NM
# 대전중부경찰서    7
# Name: OCRN_DOTW_TUE, dtype: int64
# 7 . 삼척경찰서
# [13:15:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [0.3184873]
# 12월 실제 건수 PLCST_NM
# 삼척경찰서    1
# Name: OCRN_DOTW_TUE, dtype: int64
# 8 . 괴산경찰서
# [13:15:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [2.510143]
# 12월 실제 건수 PLCST_NM
# 괴산경찰서    1
# Name: OCRN_DOTW_TUE, dtype: int64
# 9 . 서산경찰서
# [13:15:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [2.0832057]
# 12월 실제 건수 PLCST_NM
# 서산경찰서    0
# Name: OCRN_DOTW_TUE, dtype: int64
# 10 . 금산경찰서
# [13:15:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [0.3310098]
# 12월 실제 건수 PLCST_NM
# 금산경찰서    0
# Name: OCRN_DOTW_TUE, dtype: int64
# 11 . 영주경찰서
# [13:15:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [0.39855847]
# 12월 실제 건수 PLCST_NM
# 영주경찰서    1
# Name: OCRN_DOTW_TUE, dtype: int64
# 12 . 남양주경찰서
# [13:15:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: []
# 12월 실제 건수 Series([], Name: OCRN_DOTW_TUE, dtype: int64)
# 13 . 동두천경찰서
# [13:15:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [1.067325]
# 12월 실제 건수 PLCST_NM
# 동두천경찰서    3
# Name: OCRN_DOTW_TUE, dtype: int64
# 14 . 화성동탄경찰서
# [13:15:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [7.77693]
# 12월 실제 건수 PLCST_NM
# 화성동탄경찰서    6
# Name: OCRN_DOTW_TUE, dtype: int64
# 15 . 제주자치경찰단
# [13:15:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: []
# 12월 실제 건수 Series([], Name: OCRN_DOTW_TUE, dtype: int64)
# 16 . 천안동남경찰서
# [13:15:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [5.8535123]
# 12월 실제 건수 PLCST_NM
# 천안동남경찰서    6
# Name: OCRN_DOTW_TUE, dtype: int64
# 17 . 부천소사경찰서
# [13:15:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [5.055427]
# 12월 실제 건수 PLCST_NM
# 부천소사경찰서    4
# Name: OCRN_DOTW_TUE, dtype: int64
# 18 . 이천경찰서
# [13:15:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [2.758764]
# 12월 실제 건수 PLCST_NM
# 이천경찰서    2
# Name: OCRN_DOTW_TUE, dtype: int64
# 19 . ETC
# [13:15:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [64.88868]
# 12월 실제 건수 PLCST_NM
# ETC    61
# Name: OCRN_DOTW_TUE, dtype: int64
# 20 . 서울방배경찰서
# [13:15:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [0.8570334]
# 12월 실제 건수 PLCST_NM
# 서울방배경찰서    1
# Name: OCRN_DOTW_TUE, dtype: int64
# 21 . 동해경찰서
# [13:15:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [1.826833]
# 12월 실제 건수 PLCST_NM
# 동해경찰서    1
# Name: OCRN_DOTW_TUE, dtype: int64
# 22 . 진천경찰서
# [13:15:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [0.15106267]
# 12월 실제 건수 PLCST_NM
# 진천경찰서    1
# Name: OCRN_DOTW_TUE, dtype: int64
# 23 . 마산중부경찰서
# [13:15:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [1.1136885]
# 12월 실제 건수 PLCST_NM
# 마산중부경찰서    0
# Name: OCRN_DOTW_TUE, dtype: int64
# 24 . 남해경찰서
# [13:15:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [0.40877724]
# 12월 실제 건수 PLCST_NM
# 남해경찰서    1
# Name: OCRN_DOTW_TUE, dtype: int64
# 25 . 무주경찰서
# [13:15:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: []
# 12월 실제 건수 Series([], Name: OCRN_DOTW_TUE, dtype: int64)
# 26 . 창원중부경찰서
# [13:15:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [6.092949]
# 12월 실제 건수 PLCST_NM
# 창원중부경찰서    5
# Name: OCRN_DOTW_TUE, dtype: int64
# 27 . 서대문경찰서
# [13:15:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [3.234552]
# 12월 실제 건수 PLCST_NM
# 서대문경찰서    2
# Name: OCRN_DOTW_TUE, dtype: int64
# 28 . 서울용산경찰서
# [13:15:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [3.5611815]
# 12월 실제 건수 PLCST_NM
# 서울용산경찰서    1
# Name: OCRN_DOTW_TUE, dtype: int64
# 29 . 서울성북경찰서
# [13:15:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [2.0214734]
# 12월 실제 건수 PLCST_NM
# 서울성북경찰서    5
# Name: OCRN_DOTW_TUE, dtype: int64
# 30 . 성동경찰서
# [13:15:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [6.0871]
# 12월 실제 건수 PLCST_NM
# 성동경찰서    3
# Name: OCRN_DOTW_TUE, dtype: int64
# 31 . 서울강서경찰서
# [13:15:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [11.675074]
# 12월 실제 건수 PLCST_NM
# 서울강서경찰서    15
# Name: OCRN_DOTW_TUE, dtype: int64
# 32 . 부산동부경찰서
# [13:15:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [0.62700415]
# 12월 실제 건수 PLCST_NM
# 부산동부경찰서    0
# Name: OCRN_DOTW_TUE, dtype: int64
# 33 . 대구북부경찰서
# [13:15:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [3.720069]
# 12월 실제 건수 PLCST_NM
# 대구북부경찰서    3
# Name: OCRN_DOTW_TUE, dtype: int64
# 34 . 인천서부경찰서
# [13:15:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [14.15383]
# 12월 실제 건수 PLCST_NM
# 인천서부경찰서    20
# Name: OCRN_DOTW_TUE, dtype: int64
# 35 . 연수경찰서
# [13:15:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [1.5848501]
# 12월 실제 건수 PLCST_NM
# 연수경찰서    8
# Name: OCRN_DOTW_TUE, dtype: int64
# 36 . 울산남부경찰서
# [13:15:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [8.6253395]
# 12월 실제 건수 PLCST_NM
# 울산남부경찰서    11
# Name: OCRN_DOTW_TUE, dtype: int64
# 37 . 동부경찰서
# [13:15:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [4.8203044]
# 12월 실제 건수 PLCST_NM
# 동부경찰서    6
# Name: OCRN_DOTW_TUE, dtype: int64
# 38 . 서울광진경찰서
# [13:15:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [5.5008445]
# 12월 실제 건수 PLCST_NM
# 서울광진경찰서    4
# Name: OCRN_DOTW_TUE, dtype: int64
# 39 . 울산울주경찰서
# [13:15:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [3.8037884]
# 12월 실제 건수 PLCST_NM
# 울산울주경찰서    3
# Name: OCRN_DOTW_TUE, dtype: int64
# 40 . 광주북부경찰서
# [13:15:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [6.6657662]
# 12월 실제 건수 PLCST_NM
# 광주북부경찰서    4
# Name: OCRN_DOTW_TUE, dtype: int64
# 41 . 인천삼산경찰서
# [13:15:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [6.1945033]
# 12월 실제 건수 PLCST_NM
# 인천삼산경찰서    3
# Name: OCRN_DOTW_TUE, dtype: int64
# 42 . 속초경찰서
# [13:15:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [1.004104]
# 12월 실제 건수 PLCST_NM
# 속초경찰서    0
# Name: OCRN_DOTW_TUE, dtype: int64
# 43 . 포항남부경찰서
# [13:15:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [1.9583035]
# 12월 실제 건수 PLCST_NM
# 포항남부경찰서    5
# Name: OCRN_DOTW_TUE, dtype: int64
# 44 . 진해경찰서
# [13:15:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [1.6542939]
# 12월 실제 건수 PLCST_NM
# 진해경찰서    3
# Name: OCRN_DOTW_TUE, dtype: int64
# 45 . 정읍경찰서
# [13:15:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [1.3215247]
# 12월 실제 건수 PLCST_NM
# 정읍경찰서    1
# Name: OCRN_DOTW_TUE, dtype: int64
# 46 . 양주경찰서
# [13:15:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [3.1297822]
# 12월 실제 건수 PLCST_NM
# 양주경찰서    5
# Name: OCRN_DOTW_TUE, dtype: int64
# 47 . 포천경찰서
# [13:15:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [3.26534]
# 12월 실제 건수 PLCST_NM
# 포천경찰서    4
# Name: OCRN_DOTW_TUE, dtype: int64
# 48 . 가평경찰서
# [13:15:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: []
# 12월 실제 건수 Series([], Name: OCRN_DOTW_TUE, dtype: int64)
# 49 . 일산서부경찰서
# [13:15:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [3.8512423]
# 12월 실제 건수 PLCST_NM
# 일산서부경찰서    7
# Name: OCRN_DOTW_TUE, dtype: int64
# 50 . 수원중부경찰서
# [13:15:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [5.982226]
# 12월 실제 건수 PLCST_NM
# 수원중부경찰서    11
# Name: OCRN_DOTW_TUE, dtype: int64
# 51 . 안양동안경찰서
# [13:15:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [6.038493]
# 12월 실제 건수 PLCST_NM
# 안양동안경찰서    1
# Name: OCRN_DOTW_TUE, dtype: int64
# 52 . 군포경찰서
# [13:15:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [1.4471421]
# 12월 실제 건수 PLCST_NM
# 군포경찰서    5
# Name: OCRN_DOTW_TUE, dtype: int64
# 53 . 성남수정경찰서
# [13:15:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [3.927491]
# 12월 실제 건수 PLCST_NM
# 성남수정경찰서    7
# Name: OCRN_DOTW_TUE, dtype: int64
# 54 . 의왕경찰서
# [13:15:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [1.1459382]
# 12월 실제 건수 PLCST_NM
# 의왕경찰서    3
# Name: OCRN_DOTW_TUE, dtype: int64
# 55 . 하남경찰서
# [13:15:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [2.3975415]
# 12월 실제 건수 PLCST_NM
# 하남경찰서    7
# Name: OCRN_DOTW_TUE, dtype: int64
# 56 . 여주경찰서
# [13:15:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [0.6294102]
# 12월 실제 건수 PLCST_NM
# 여주경찰서    0
# Name: OCRN_DOTW_TUE, dtype: int64
# 57 . 횡성경찰서
# [13:15:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [0.9821489]
# 12월 실제 건수 PLCST_NM
# 횡성경찰서    0
# Name: OCRN_DOTW_TUE, dtype: int64
# 58 . 고흥경찰서
# [13:15:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [0]
# 12월 실제 건수 PLCST_NM
# 고흥경찰서    0
# Name: OCRN_DOTW_TUE, dtype: int64
# 59 . 담양경찰서
# [13:15:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: []
# 12월 실제 건수 Series([], Name: OCRN_DOTW_TUE, dtype: int64)
# 60 . 서울수서경찰서
# [13:15:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [2.364678]
# 12월 실제 건수 PLCST_NM
# 서울수서경찰서    4
# Name: OCRN_DOTW_TUE, dtype: int64
# 61 . 인천중부경찰서
# [13:15:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [2.5132418]
# 12월 실제 건수 PLCST_NM
# 인천중부경찰서    0
# Name: OCRN_DOTW_TUE, dtype: int64
# 62 . 전주덕진경찰서
# [13:15:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [5.5923586]
# 12월 실제 건수 PLCST_NM
# 전주덕진경찰서    7
# Name: OCRN_DOTW_TUE, dtype: int64
# 63 . 대전동부경찰서
# [13:15:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [2.4336247]
# 12월 실제 건수 PLCST_NM
# 대전동부경찰서    1
# Name: OCRN_DOTW_TUE, dtype: int64
# 64 . 제주서부경찰서
# [13:15:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [3.2562516]
# 12월 실제 건수 PLCST_NM
# 제주서부경찰서    1
# Name: OCRN_DOTW_TUE, dtype: int64
# 65 . 김해중부경찰서
# [13:15:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [5.523549]
# 12월 실제 건수 PLCST_NM
# 김해중부경찰서    6
# Name: OCRN_DOTW_TUE, dtype: int64
# 66 . 태백경찰서
# [13:15:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [0]
# 12월 실제 건수 PLCST_NM
# 태백경찰서    0
# Name: OCRN_DOTW_TUE, dtype: int64
# 67 . 양구경찰서
# [13:15:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: []
# 12월 실제 건수 Series([], Name: OCRN_DOTW_TUE, dtype: int64)
# 68 . 충주경찰서
# [13:15:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [6.3558073]
# 12월 실제 건수 PLCST_NM
# 충주경찰서    4
# Name: OCRN_DOTW_TUE, dtype: int64
# 69 . 서천경찰서
# [13:15:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: []
# 12월 실제 건수 Series([], Name: OCRN_DOTW_TUE, dtype: int64)
# 70 . 여수경찰서
# [13:15:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [2.5520675]
# 12월 실제 건수 PLCST_NM
# 여수경찰서    3
# Name: OCRN_DOTW_TUE, dtype: int64
# 71 . 서귀포경찰서
# [13:15:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [0.6659532]
# 12월 실제 건수 PLCST_NM
# 서귀포경찰서    1
# Name: OCRN_DOTW_TUE, dtype: int64
# 72 . 구리경찰서
# [13:15:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [3.7220945]
# 12월 실제 건수 PLCST_NM
# 구리경찰서    2
# Name: OCRN_DOTW_TUE, dtype: int64
# 73 . 태안경찰서
# [13:15:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [1.3067677]
# 12월 실제 건수 PLCST_NM
# 태안경찰서    0
# Name: OCRN_DOTW_TUE, dtype: int64
# 74 . 오산경찰서
# [13:15:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [5.0984793]
# 12월 실제 건수 PLCST_NM
# 오산경찰서    4
# Name: OCRN_DOTW_TUE, dtype: int64
# 75 . 천안서북경찰서
# [13:15:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [5.931629]
# 12월 실제 건수 PLCST_NM
# 천안서북경찰서    3
# Name: OCRN_DOTW_TUE, dtype: int64
# 76 . 대구강북경찰서
# [13:15:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [3.8750196]
# 12월 실제 건수 PLCST_NM
# 대구강북경찰서    10
# Name: OCRN_DOTW_TUE, dtype: int64
# 77 . 대전유성경찰서
# [13:15:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [1.9528382]
# 12월 실제 건수 PLCST_NM
# 대전유성경찰서    2
# Name: OCRN_DOTW_TUE, dtype: int64
# 78 . 수원남부경찰서
# [13:15:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [9.962614]
# 12월 실제 건수 PLCST_NM
# 수원남부경찰서    10
# Name: OCRN_DOTW_TUE, dtype: int64
# 79 . 안양만안경찰서
# [13:15:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [6.9489555]
# 12월 실제 건수 PLCST_NM
# 안양만안경찰서    2
# Name: OCRN_DOTW_TUE, dtype: int64
# 80 . 광명경찰서
# [13:15:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [9.594979]
# 12월 실제 건수 PLCST_NM
# 광명경찰서    16
# Name: OCRN_DOTW_TUE, dtype: int64
# 81 . 안산단원경찰서
# [13:15:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [9.376356]
# 12월 실제 건수 PLCST_NM
# 안산단원경찰서    3
# Name: OCRN_DOTW_TUE, dtype: int64
# 82 . 용인동부경찰서
# [13:15:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [5.7378645]
# 12월 실제 건수 PLCST_NM
# 용인동부경찰서    7
# Name: OCRN_DOTW_TUE, dtype: int64
# 83 . 김포경찰서
# [13:15:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [10.125833]
# 12월 실제 건수 PLCST_NM
# 김포경찰서    7
# Name: OCRN_DOTW_TUE, dtype: int64
# 84 . 서울서초경찰서
# [13:15:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [2.1705437]
# 12월 실제 건수 PLCST_NM
# 서울서초경찰서    2
# Name: OCRN_DOTW_TUE, dtype: int64
# 85 . 부산사상경찰서
# [13:15:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [2.9577699]
# 12월 실제 건수 PLCST_NM
# 부산사상경찰서    0
# Name: OCRN_DOTW_TUE, dtype: int64
# 86 . 부산연제경찰서
# [13:15:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [2.067296]
# 12월 실제 건수 PLCST_NM
# 부산연제경찰서    1
# Name: OCRN_DOTW_TUE, dtype: int64
# 87 . 광주동부경찰서
# [13:15:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [4.7096033]
# 12월 실제 건수 PLCST_NM
# 광주동부경찰서    4
# Name: OCRN_DOTW_TUE, dtype: int64
# 88 . 강진경찰서
# [13:15:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [0]
# 12월 실제 건수 PLCST_NM
# 강진경찰서    0
# Name: OCRN_DOTW_TUE, dtype: int64
# 89 . 서울남대문경찰서
# [13:15:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [0.42490232]
# 12월 실제 건수 PLCST_NM
# 서울남대문경찰서    0
# Name: OCRN_DOTW_TUE, dtype: int64
# 90 . 옥천경찰서
# [13:15:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [0.61131656]
# 12월 실제 건수 PLCST_NM
# 옥천경찰서    1
# Name: OCRN_DOTW_TUE, dtype: int64
# 91 . 단양경찰서
# [13:15:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: []
# 12월 실제 건수 Series([], Name: OCRN_DOTW_TUE, dtype: int64)
# 92 . 의성경찰서
# [13:15:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [0.40497732]
# 12월 실제 건수 PLCST_NM
# 의성경찰서    0
# Name: OCRN_DOTW_TUE, dtype: int64
# 93 . 영등포경찰서
# [13:15:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [4.3192825]
# 12월 실제 건수 PLCST_NM
# 영등포경찰서    10
# Name: OCRN_DOTW_TUE, dtype: int64
# 94 . 부산동래경찰서
# [13:15:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [5.073891]
# 12월 실제 건수 PLCST_NM
# 부산동래경찰서    6
# Name: OCRN_DOTW_TUE, dtype: int64
# 95 . 부산사하경찰서
# [13:15:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [6.3941655]
# 12월 실제 건수 PLCST_NM
# 부산사하경찰서    13
# Name: OCRN_DOTW_TUE, dtype: int64
# 96 . 광주남부경찰서
# [13:15:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [3.1031947]
# 12월 실제 건수 PLCST_NM
# 광주남부경찰서    7
# Name: OCRN_DOTW_TUE, dtype: int64
# 97 . 대전대덕경찰서
# [13:15:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [3.899726]
# 12월 실제 건수 PLCST_NM
# 대전대덕경찰서    3
# Name: OCRN_DOTW_TUE, dtype: int64
# 98 . 강릉경찰서
# [13:15:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [3.5294704]
# 12월 실제 건수 PLCST_NM
# 강릉경찰서    1
# Name: OCRN_DOTW_TUE, dtype: int64
# 99 . 당진경찰서
# [13:15:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [2.1820543]
# 12월 실제 건수 PLCST_NM
# 당진경찰서    2
# Name: OCRN_DOTW_TUE, dtype: int64
# 100 . 진주경찰서
# [13:15:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [8.212471]
# 12월 실제 건수 PLCST_NM
# 진주경찰서    2
# Name: OCRN_DOTW_TUE, dtype: int64
# 101 . 통영경찰서
# [13:15:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [0.70456934]
# 12월 실제 건수 PLCST_NM
# 통영경찰서    0
# Name: OCRN_DOTW_TUE, dtype: int64
# 102 . 거제경찰서
# [13:15:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [2.2220285]
# 12월 실제 건수 PLCST_NM
# 거제경찰서    2
# Name: OCRN_DOTW_TUE, dtype: int64
# 103 . 함양경찰서
# [13:15:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [0.78358775]
# 12월 실제 건수 PLCST_NM
# 함양경찰서    0
# Name: OCRN_DOTW_TUE, dtype: int64
# 104 . 광양경찰서
# [13:15:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [0.52051204]
# 12월 실제 건수 PLCST_NM
# 광양경찰서    0
# Name: OCRN_DOTW_TUE, dtype: int64
# 105 . 일산동부경찰서
# [13:15:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [2.1793756]
# 12월 실제 건수 PLCST_NM
# 일산동부경찰서    1
# Name: OCRN_DOTW_TUE, dtype: int64
# 106 . 기장경찰서
# [13:15:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [4.532956]
# 12월 실제 건수 PLCST_NM
# 기장경찰서    4
# Name: OCRN_DOTW_TUE, dtype: int64
# 107 . 세종경찰서
# [13:15:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: []
# 12월 실제 건수 Series([], Name: OCRN_DOTW_TUE, dtype: int64)
# 108 . 용인서부경찰서
# [13:15:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [2.7520518]
# 12월 실제 건수 PLCST_NM
# 용인서부경찰서    2
# Name: OCRN_DOTW_TUE, dtype: int64
# 109 . 익산경찰서
# [13:15:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [3.763735]
# 12월 실제 건수 PLCST_NM
# 익산경찰서    3
# Name: OCRN_DOTW_TUE, dtype: int64
# 110 . 서울혜화경찰서
# [13:15:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [0.04523543]
# 12월 실제 건수 PLCST_NM
# 서울혜화경찰서    0
# Name: OCRN_DOTW_TUE, dtype: int64
# 111 . 홍천경찰서
# [13:15:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [0]
# 12월 실제 건수 PLCST_NM
# 홍천경찰서    2
# Name: OCRN_DOTW_TUE, dtype: int64
# 112 . 영월경찰서
# [13:15:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [0.19634482]
# 12월 실제 건수 PLCST_NM
# 영월경찰서    0
# Name: OCRN_DOTW_TUE, dtype: int64
# 113 . 문경경찰서
# [13:15:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: []
# 12월 실제 건수 Series([], Name: OCRN_DOTW_TUE, dtype: int64)
# 114 . 봉화경찰서
# [13:15:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: []
# 12월 실제 건수 Series([], Name: OCRN_DOTW_TUE, dtype: int64)
# 115 . 합천경찰서
# [13:15:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: []
# 12월 실제 건수 Series([], Name: OCRN_DOTW_TUE, dtype: int64)
# 116 . 진안경찰서
# [13:15:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: []
# 12월 실제 건수 Series([], Name: OCRN_DOTW_TUE, dtype: int64)
# 117 . 고령경찰서
# [13:15:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: []
# 12월 실제 건수 Series([], Name: OCRN_DOTW_TUE, dtype: int64)
# 118 . 철원경찰서
# [13:15:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [0.45250663]
# 12월 실제 건수 PLCST_NM
# 철원경찰서    0
# Name: OCRN_DOTW_TUE, dtype: int64
# 119 . 서울서부경찰서
# [13:15:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [5.3840017]
# 12월 실제 건수 PLCST_NM
# 서울서부경찰서    4
# Name: OCRN_DOTW_TUE, dtype: int64
# 120 . 서울양천경찰서
# [13:15:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [2.9623547]
# 12월 실제 건수 PLCST_NM
# 서울양천경찰서    2
# Name: OCRN_DOTW_TUE, dtype: int64
# 121 . 서울송파경찰서
# [13:15:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [7.291438]
# 12월 실제 건수 PLCST_NM
# 서울송파경찰서    7
# Name: OCRN_DOTW_TUE, dtype: int64
# 122 . 서울도봉경찰서
# [13:15:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [6.8280687]
# 12월 실제 건수 PLCST_NM
# 서울도봉경찰서    2
# Name: OCRN_DOTW_TUE, dtype: int64
# 123 . 부산북부경찰서
# [13:15:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [5.663178]
# 12월 실제 건수 PLCST_NM
# 부산북부경찰서    2
# Name: OCRN_DOTW_TUE, dtype: int64
# 124 . 대구동부경찰서
# [13:15:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [2.365529]
# 12월 실제 건수 PLCST_NM
# 대구동부경찰서    8
# Name: OCRN_DOTW_TUE, dtype: int64
# 125 . 대구달성경찰서
# [13:15:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [2.8459258]
# 12월 실제 건수 PLCST_NM
# 대구달성경찰서    4
# Name: OCRN_DOTW_TUE, dtype: int64
# 126 . 인천남동경찰서
# [13:15:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [10.610093]
# 12월 실제 건수 PLCST_NM
# 인천남동경찰서    3
# Name: OCRN_DOTW_TUE, dtype: int64
# 127 . 청주흥덕경찰서
# [13:15:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [2.3132126]
# 12월 실제 건수 PLCST_NM
# 청주흥덕경찰서    7
# Name: OCRN_DOTW_TUE, dtype: int64
# 128 . 김해서부경찰서
# [13:15:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [8.295205]
# 12월 실제 건수 PLCST_NM
# 김해서부경찰서    7
# Name: OCRN_DOTW_TUE, dtype: int64
# 129 . 부산진경찰서
# [13:15:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [6.1263046]
# 12월 실제 건수 PLCST_NM
# 부산진경찰서    0
# Name: OCRN_DOTW_TUE, dtype: int64
# 130 . 원주경찰서
# [13:15:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [3.5329165]
# 12월 실제 건수 PLCST_NM
# 원주경찰서    3
# Name: OCRN_DOTW_TUE, dtype: int64
# 131 . 논산경찰서
# [13:15:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [2.6768382]
# 12월 실제 건수 PLCST_NM
# 논산경찰서    1
# Name: OCRN_DOTW_TUE, dtype: int64
# 132 . 경산경찰서
# [13:15:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [3.1232657]
# 12월 실제 건수 PLCST_NM
# 경산경찰서    7
# Name: OCRN_DOTW_TUE, dtype: int64
# 133 . 거창경찰서
# [13:15:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [0.04372841]
# 12월 실제 건수 PLCST_NM
# 거창경찰서    0
# Name: OCRN_DOTW_TUE, dtype: int64
# 134 . 안산상록경찰서
# [13:15:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [10.43668]
# 12월 실제 건수 PLCST_NM
# 안산상록경찰서    4
# Name: OCRN_DOTW_TUE, dtype: int64
# 135 . 시흥경찰서
# [13:15:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [7.356469]
# 12월 실제 건수 PLCST_NM
# 시흥경찰서    14
# Name: OCRN_DOTW_TUE, dtype: int64
# 136 . 광주경찰서
# [13:15:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [13.957153]
# 12월 실제 건수 PLCST_NM
# 광주경찰서    5
# Name: OCRN_DOTW_TUE, dtype: int64
# 137 . 안성경찰서
# [13:15:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [2.6475382]
# 12월 실제 건수 PLCST_NM
# 안성경찰서    4
# Name: OCRN_DOTW_TUE, dtype: int64
# 138 . 의정부경찰서
# [13:15:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [9.032937]
# 12월 실제 건수 PLCST_NM
# 의정부경찰서    17
# Name: OCRN_DOTW_TUE, dtype: int64
# 139 . 부산영도경찰서
# [13:15:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [1.6394365]
# 12월 실제 건수 PLCST_NM
# 부산영도경찰서    0
# Name: OCRN_DOTW_TUE, dtype: int64
# 140 . 홍성경찰서
# [13:15:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [0.73024493]
# 12월 실제 건수 PLCST_NM
# 홍성경찰서    2
# Name: OCRN_DOTW_TUE, dtype: int64
# 141 . 부안경찰서
# [13:15:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [0.09024456]
# 12월 실제 건수 PLCST_NM
# 부안경찰서    0
# Name: OCRN_DOTW_TUE, dtype: int64
# 142 . 연천경찰서
# [13:15:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [0.9651656]
# 12월 실제 건수 PLCST_NM
# 연천경찰서    0
# Name: OCRN_DOTW_TUE, dtype: int64
# 143 . 화성서부경찰서
# [13:15:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [3.1674209]
# 12월 실제 건수 PLCST_NM
# 화성서부경찰서    7
# Name: OCRN_DOTW_TUE, dtype: int64
# 144 . 대구남부경찰서
# [13:15:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [1.6602783]
# 12월 실제 건수 PLCST_NM
# 대구남부경찰서    2
# Name: OCRN_DOTW_TUE, dtype: int64
# 145 . 예산경찰서
# [13:15:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [1.3233631]
# 12월 실제 건수 PLCST_NM
# 예산경찰서    0
# Name: OCRN_DOTW_TUE, dtype: int64
# 146 . 서울마포경찰서
# [13:15:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [7.660977]
# 12월 실제 건수 PLCST_NM
# 서울마포경찰서    5
# Name: OCRN_DOTW_TUE, dtype: int64
# 147 . 서울구로경찰서
# [13:15:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [9.06523]
# 12월 실제 건수 PLCST_NM
# 서울구로경찰서    8
# Name: OCRN_DOTW_TUE, dtype: int64
# 148 . 은평경찰서
# [13:15:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [16.026974]
# 12월 실제 건수 PLCST_NM
# 은평경찰서    7
# Name: OCRN_DOTW_TUE, dtype: int64
# 149 . 대구달서경찰서
# [13:15:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [3.7654364]
# 12월 실제 건수 PLCST_NM
# 대구달서경찰서    3
# Name: OCRN_DOTW_TUE, dtype: int64
# 150 . 금천경찰서
# [13:15:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [2.4566247]
# 12월 실제 건수 PLCST_NM
# 금천경찰서    3
# Name: OCRN_DOTW_TUE, dtype: int64
# 151 . 서울동대문경찰서
# [13:15:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [3.268955]
# 12월 실제 건수 PLCST_NM
# 서울동대문경찰서    3
# Name: OCRN_DOTW_TUE, dtype: int64
# 152 . 광주광산경찰서
# [13:15:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [7.5158467]
# 12월 실제 건수 PLCST_NM
# 광주광산경찰서    10
# Name: OCRN_DOTW_TUE, dtype: int64
# 153 . 보령경찰서
# [13:15:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [0.7054412]
# 12월 실제 건수 PLCST_NM
# 보령경찰서    1
# Name: OCRN_DOTW_TUE, dtype: int64
# 154 . 아산경찰서
# [13:15:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [3.5005734]
# 12월 실제 건수 PLCST_NM
# 아산경찰서    1
# Name: OCRN_DOTW_TUE, dtype: int64
# 155 . 경주경찰서
# [13:15:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [2.4158058]
# 12월 실제 건수 PLCST_NM
# 경주경찰서    4
# Name: OCRN_DOTW_TUE, dtype: int64
# 156 . 마산동부경찰서
# [13:15:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [2.4768739]
# 12월 실제 건수 PLCST_NM
# 마산동부경찰서    2
# Name: OCRN_DOTW_TUE, dtype: int64
# 157 . 사천경찰서
# [13:15:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [0]
# 12월 실제 건수 PLCST_NM
# 사천경찰서    0
# Name: OCRN_DOTW_TUE, dtype: int64
# 158 . 군산경찰서
# [13:15:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [1.4880735]
# 12월 실제 건수 PLCST_NM
# 군산경찰서    4
# Name: OCRN_DOTW_TUE, dtype: int64
# 159 . 완주경찰서
# [13:15:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [0.27727938]
# 12월 실제 건수 PLCST_NM
# 완주경찰서    0
# Name: OCRN_DOTW_TUE, dtype: int64
# 160 . 순천경찰서
# [13:15:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [3.1621218]
# 12월 실제 건수 PLCST_NM
# 순천경찰서    10
# Name: OCRN_DOTW_TUE, dtype: int64
# 161 . 평택경찰서
# [13:15:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [7.179729]
# 12월 실제 건수 PLCST_NM
# 평택경찰서    4
# Name: OCRN_DOTW_TUE, dtype: int64
# 162 . 양평경찰서
# [13:15:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [0.48905605]
# 12월 실제 건수 PLCST_NM
# 양평경찰서    0
# Name: OCRN_DOTW_TUE, dtype: int64
# 163 . 부산서부경찰서
# [13:15:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [2.3817334]
# 12월 실제 건수 PLCST_NM
# 부산서부경찰서    0
# Name: OCRN_DOTW_TUE, dtype: int64
# 164 . 부여경찰서
# [13:15:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [0.94131136]
# 12월 실제 건수 PLCST_NM
# 부여경찰서    1
# Name: OCRN_DOTW_TUE, dtype: int64
# 165 . 청양경찰서
# [13:15:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: []
# 12월 실제 건수 Series([], Name: OCRN_DOTW_TUE, dtype: int64)
# 166 . 나주경찰서
# [13:15:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [0.09670204]
# 12월 실제 건수 PLCST_NM
# 나주경찰서    0
# Name: OCRN_DOTW_TUE, dtype: int64
# 167 . 해남경찰서
# [13:15:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [0.42161825]
# 12월 실제 건수 PLCST_NM
# 해남경찰서    1
# Name: OCRN_DOTW_TUE, dtype: int64
# 168 . 고성경찰서
# 12월 예상 건수: [0]
# 169 . 김제경찰서
# [13:15:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [1.2638028]
# 12월 실제 건수 PLCST_NM
# 김제경찰서    0
# Name: OCRN_DOTW_TUE, dtype: int64
# 170 . 영암경찰서
# [13:15:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: []
# 12월 실제 건수 Series([], Name: OCRN_DOTW_TUE, dtype: int64)
# 171 . 창원서부경찰서
# [13:15:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [0.9918749]
# 12월 실제 건수 PLCST_NM
# 창원서부경찰서    0
# Name: OCRN_DOTW_TUE, dtype: int64
# 172 . 서울종암경찰서
# [13:15:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [1.3602803]
# 12월 실제 건수 PLCST_NM
# 서울종암경찰서    1
# Name: OCRN_DOTW_TUE, dtype: int64
# 173 . 부산남부경찰서
# [13:15:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [5.680746]
# 12월 실제 건수 PLCST_NM
# 부산남부경찰서    3
# Name: OCRN_DOTW_TUE, dtype: int64
# 174 . 대구중부경찰서
# [13:15:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [4.2409086]
# 12월 실제 건수 PLCST_NM
# 대구중부경찰서    1
# Name: OCRN_DOTW_TUE, dtype: int64
# 175 . 인천부평경찰서
# [13:15:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [1.2313479]
# 12월 실제 건수 PLCST_NM
# 인천부평경찰서    0
# Name: OCRN_DOTW_TUE, dtype: int64
# 176 . 인천계양경찰서
# [13:15:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [3.2926302]
# 12월 실제 건수 PLCST_NM
# 인천계양경찰서    5
# Name: OCRN_DOTW_TUE, dtype: int64
# 177 . 서울강북경찰서
# [13:15:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [6.0783544]
# 12월 실제 건수 PLCST_NM
# 서울강북경찰서    4
# Name: OCRN_DOTW_TUE, dtype: int64
# 178 . 광주서부경찰서
# [13:15:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [5.410821]
# 12월 실제 건수 PLCST_NM
# 광주서부경찰서    4
# Name: OCRN_DOTW_TUE, dtype: int64
# 179 . 공주경찰서
# [13:15:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [1.6478695]
# 12월 실제 건수 PLCST_NM
# 공주경찰서    3
# Name: OCRN_DOTW_TUE, dtype: int64
# 180 . 칠곡경찰서
# [13:15:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [1.4458482]
# 12월 실제 건수 PLCST_NM
# 칠곡경찰서    0
# Name: OCRN_DOTW_TUE, dtype: int64
# 181 . 창녕경찰서
# [13:15:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [0.10441446]
# 12월 실제 건수 PLCST_NM
# 창녕경찰서    0
# Name: OCRN_DOTW_TUE, dtype: int64
# 182 . 목포경찰서
# [13:15:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [6.248724]
# 12월 실제 건수 PLCST_NM
# 목포경찰서    3
# Name: OCRN_DOTW_TUE, dtype: int64
# 183 . 구례경찰서
# [13:15:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: []
# 12월 실제 건수 Series([], Name: OCRN_DOTW_TUE, dtype: int64)
# 184 . 화순경찰서
# [13:15:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [0.8603184]
# 12월 실제 건수 PLCST_NM
# 화순경찰서    0
# Name: OCRN_DOTW_TUE, dtype: int64
# 185 . 파주경찰서
# [13:15:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [9.42515]
# 12월 실제 건수 PLCST_NM
# 파주경찰서    4
# Name: OCRN_DOTW_TUE, dtype: int64
# 186 . 청주청원경찰서
# [13:15:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [3.800669]
# 12월 실제 건수 PLCST_NM
# 청주청원경찰서    2
# Name: OCRN_DOTW_TUE, dtype: int64
# 187 . 성남중원경찰서
# [13:15:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [7.8663974]
# 12월 실제 건수 PLCST_NM
# 성남중원경찰서    6
# Name: OCRN_DOTW_TUE, dtype: int64
# 188 . 분당경찰서
# [13:15:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [5.3626647]
# 12월 실제 건수 PLCST_NM
# 분당경찰서    2
# Name: OCRN_DOTW_TUE, dtype: int64
# 189 . 부천오정경찰서
# [13:15:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [3.8727345]
# 12월 실제 건수 PLCST_NM
# 부천오정경찰서    4
# Name: OCRN_DOTW_TUE, dtype: int64
# 190 . 고양경찰서
# [13:15:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [4.4285316]
# 12월 실제 건수 PLCST_NM
# 고양경찰서    6
# Name: OCRN_DOTW_TUE, dtype: int64
# 191 . 영광경찰서
# [13:15:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [0.24776596]
# 12월 실제 건수 PLCST_NM
# 영광경찰서    0
# Name: OCRN_DOTW_TUE, dtype: int64
# 192 . 제천경찰서
# [13:15:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [3.7559257]
# 12월 실제 건수 PLCST_NM
# 제천경찰서    3
# Name: OCRN_DOTW_TUE, dtype: int64
# 193 . 음성경찰서
# [13:15:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [1.010408]
# 12월 실제 건수 PLCST_NM
# 음성경찰서    0
# Name: OCRN_DOTW_TUE, dtype: int64
# 194 . 장흥경찰서
# [13:15:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [1.344423]
# 12월 실제 건수 PLCST_NM
# 장흥경찰서    1
# Name: OCRN_DOTW_TUE, dtype: int64
# 195 . 보성경찰서
# [13:15:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [0.08486292]
# 12월 실제 건수 PLCST_NM
# 보성경찰서    0
# Name: OCRN_DOTW_TUE, dtype: int64
# 196 . 김천경찰서
# [13:15:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [2.2908535]
# 12월 실제 건수 PLCST_NM
# 김천경찰서    2
# Name: OCRN_DOTW_TUE, dtype: int64
# 197 . 서울중부경찰서
# [13:15:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [5.4671845]
# 12월 실제 건수 PLCST_NM
# 서울중부경찰서    5
# Name: OCRN_DOTW_TUE, dtype: int64
# 198 . 서울관악경찰서
# [13:15:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [0.7934779]
# 12월 실제 건수 PLCST_NM
# 서울관악경찰서    4
# Name: OCRN_DOTW_TUE, dtype: int64
# 199 . 서울강동경찰서
# [13:15:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [10.630736]
# 12월 실제 건수 PLCST_NM
# 서울강동경찰서    6
# Name: OCRN_DOTW_TUE, dtype: int64
# 200 . 부산중부경찰서
# [13:15:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [1.7674851]
# 12월 실제 건수 PLCST_NM
# 부산중부경찰서    0
# Name: OCRN_DOTW_TUE, dtype: int64
# 201 . 부산금정경찰서
# [13:15:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [5.1046147]
# 12월 실제 건수 PLCST_NM
# 부산금정경찰서    5
# Name: OCRN_DOTW_TUE, dtype: int64
# 202 . 대구서부경찰서
# [13:15:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [1.1421161]
# 12월 실제 건수 PLCST_NM
# 대구서부경찰서    2
# Name: OCRN_DOTW_TUE, dtype: int64
# 203 . 대구수성경찰서
# [13:15:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [10.37097]
# 12월 실제 건수 PLCST_NM
# 대구수성경찰서    9
# Name: OCRN_DOTW_TUE, dtype: int64
# 204 . 서울동작경찰서
# [13:15:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [3.1976964]
# 12월 실제 건수 PLCST_NM
# 서울동작경찰서    5
# Name: OCRN_DOTW_TUE, dtype: int64
# 205 . 대전서부경찰서
# [13:15:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [1.6408752]
# 12월 실제 건수 PLCST_NM
# 대전서부경찰서    1
# Name: OCRN_DOTW_TUE, dtype: int64
# 206 . 대전둔산경찰서
# [13:15:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [3.9714317]
# 12월 실제 건수 PLCST_NM
# 대전둔산경찰서    6
# Name: OCRN_DOTW_TUE, dtype: int64
# 207 . 제주경찰청
# 12월 예상 건수: [0]
# 208 . 춘천경찰서
# [13:15:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [3.7385023]
# 12월 실제 건수 PLCST_NM
# 춘천경찰서    4
# Name: OCRN_DOTW_TUE, dtype: int64
# 209 . 포항북부경찰서
# [13:15:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [4.4206023]
# 12월 실제 건수 PLCST_NM
# 포항북부경찰서    5
# Name: OCRN_DOTW_TUE, dtype: int64
# 210 . 구미경찰서
# [13:15:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [5.3449755]
# 12월 실제 건수 PLCST_NM
# 구미경찰서    0
# Name: OCRN_DOTW_TUE, dtype: int64
# 211 . 상주경찰서
# [13:15:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [0.53470826]
# 12월 실제 건수 PLCST_NM
# 상주경찰서    0
# Name: OCRN_DOTW_TUE, dtype: int64
# 212 . 양산경찰서
# [13:15:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [5.284896]
# 12월 실제 건수 PLCST_NM
# 양산경찰서    4
# Name: OCRN_DOTW_TUE, dtype: int64
# 213 . 함안경찰서
# [13:15:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [0.2713351]
# 12월 실제 건수 PLCST_NM
# 함안경찰서    0
# Name: OCRN_DOTW_TUE, dtype: int64
# 214 . 남원경찰서
# [13:15:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [0]
# 12월 실제 건수 PLCST_NM
# 남원경찰서    1
# Name: OCRN_DOTW_TUE, dtype: int64
# 215 . 무안경찰서
# [13:15:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [0.8591185]
# 12월 실제 건수 PLCST_NM
# 무안경찰서    2
# Name: OCRN_DOTW_TUE, dtype: int64
# 216 . 인천논현경찰서
# [13:15:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [6.6844416]
# 12월 실제 건수 PLCST_NM
# 인천논현경찰서    7
# Name: OCRN_DOTW_TUE, dtype: int64
# 217 . 인천미추홀경찰서
# [13:15:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [3.1883771]
# 12월 실제 건수 PLCST_NM
# 인천미추홀경찰서    9
# Name: OCRN_DOTW_TUE, dtype: int64
# 218 . 청주상당경찰서
# [13:15:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [6.392915]
# 12월 실제 건수 PLCST_NM
# 청주상당경찰서    3
# Name: OCRN_DOTW_TUE, dtype: int64
# 219 . 수원서부경찰서
# [13:15:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [6.4293733]
# 12월 실제 건수 PLCST_NM
# 수원서부경찰서    7
# Name: OCRN_DOTW_TUE, dtype: int64
# 220 . 부천원미경찰서
# [13:15:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [8.245269]
# 12월 실제 건수 PLCST_NM
# 부천원미경찰서    3
# Name: OCRN_DOTW_TUE, dtype: int64
# 221 . 강남경찰서
# [13:15:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [3.391854]
# 12월 실제 건수 PLCST_NM
# 강남경찰서    4
# Name: OCRN_DOTW_TUE, dtype: int64
# 222 . 제주동부경찰서
# [13:15:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [3.3983858]
# 12월 실제 건수 PLCST_NM
# 제주동부경찰서    6
# Name: OCRN_DOTW_TUE, dtype: int64
# 223 . 안동경찰서
# [13:15:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [0.66252536]
# 12월 실제 건수 PLCST_NM
# 안동경찰서    1
# Name: OCRN_DOTW_TUE, dtype: int64
# 224 . 평창경찰서
# [13:15:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: []
# 12월 실제 건수 Series([], Name: OCRN_DOTW_TUE, dtype: int64)
# 225 . 영천경찰서
# [13:15:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [0]
# 12월 실제 건수 PLCST_NM
# 영천경찰서    0
# Name: OCRN_DOTW_TUE, dtype: int64
# 226 . 장수경찰서
# [13:15:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: []
# 12월 실제 건수 Series([], Name: OCRN_DOTW_TUE, dtype: int64)
# 227 . 밀양경찰서
# [13:15:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [0.2105506]
# 12월 실제 건수 PLCST_NM
# 밀양경찰서    0
# Name: OCRN_DOTW_TUE, dtype: int64
# 228 . 보은경찰서
# [13:15:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: []
# 12월 실제 건수 Series([], Name: OCRN_DOTW_TUE, dtype: int64)
# 229 . 영동경찰서
# [13:15:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [0.786686]
# 12월 실제 건수 PLCST_NM
# 영동경찰서    0
# Name: OCRN_DOTW_TUE, dtype: int64
# 230 . 하동경찰서
# [13:15:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [0.00283]
# 12월 실제 건수 PLCST_NM
# 하동경찰서    0
# Name: OCRN_DOTW_TUE, dtype: int64
# 231 . 정선경찰서
# [13:15:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: []
# 12월 실제 건수 Series([], Name: OCRN_DOTW_TUE, dtype: int64)
# 232 . 예천경찰서
# [13:15:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: []
# 12월 실제 건수 Series([], Name: OCRN_DOTW_TUE, dtype: int64)
# 233 . 청도경찰서
# [13:15:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [0.8295728]
# 12월 실제 건수 PLCST_NM
# 청도경찰서    0
# Name: OCRN_DOTW_TUE, dtype: int64
# 234 . 인천강화경찰서
# [13:15:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [0.16170198]
# 12월 실제 건수 PLCST_NM
# 인천강화경찰서    0
# Name: OCRN_DOTW_TUE, dtype: int64
# 235 . 장성경찰서
# [13:15:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: []
# 12월 실제 건수 Series([], Name: OCRN_DOTW_TUE, dtype: int64)
# 236 . 울진경찰서
# [13:15:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: []
# 12월 실제 건수 Series([], Name: OCRN_DOTW_TUE, dtype: int64)
# 237 . 진도경찰서
# [13:15:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [0.71209055]
# 12월 실제 건수 PLCST_NM
# 진도경찰서    0
# Name: OCRN_DOTW_TUE, dtype: int64
# 238 . 화천경찰서
# [13:15:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: []
# 12월 실제 건수 Series([], Name: OCRN_DOTW_TUE, dtype: int64)
# 239 . 부산강서경찰서
# [13:15:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [1.7165384]
# 12월 실제 건수 PLCST_NM
# 부산강서경찰서    1
# Name: OCRN_DOTW_TUE, dtype: int64
# 240 . 서울종로경찰서
# [13:15:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [1.4345751]
# 12월 실제 건수 PLCST_NM
# 서울종로경찰서    0
# Name: OCRN_DOTW_TUE, dtype: int64
# 241 . 영덕경찰서
# [13:15:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: []
# 12월 실제 건수 Series([], Name: OCRN_DOTW_TUE, dtype: int64)
# 242 . 완도경찰서
# [13:15:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [0.04488921]
# 12월 실제 건수 PLCST_NM
# 완도경찰서    1
# Name: OCRN_DOTW_TUE, dtype: int64
# 243 . 함평경찰서
# [13:15:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: []
# 12월 실제 건수 Series([], Name: OCRN_DOTW_TUE, dtype: int64)
# 244 . 서울경찰청
# [13:15:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: []
# 12월 실제 건수 Series([], Name: OCRN_DOTW_TUE, dtype: int64)
# 245 . 고창경찰서
# [13:15:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [0.10778791]
# 12월 실제 건수 PLCST_NM
# 고창경찰서    0
# Name: OCRN_DOTW_TUE, dtype: int64
# 246 . 청송경찰서
# [13:15:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: []
# 12월 실제 건수 Series([], Name: OCRN_DOTW_TUE, dtype: int64)
# 247 . 인제경찰서
# [13:15:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [0.00030318]
# 12월 실제 건수 PLCST_NM
# 인제경찰서    0
# Name: OCRN_DOTW_TUE, dtype: int64
# 248 . 과천경찰서
# [13:15:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [1.9044114]
# 12월 실제 건수 PLCST_NM
# 과천경찰서    1
# Name: OCRN_DOTW_TUE, dtype: int64
# 249 . 경비교통과
# [13:15:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: []
# 12월 실제 건수 Series([], Name: OCRN_DOTW_TUE, dtype: int64)
# 250 . 산청경찰서
# [13:15:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: []
# 12월 실제 건수 Series([], Name: OCRN_DOTW_TUE, dtype: int64)
# 251 . 군위경찰서
# [13:15:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: []
# 12월 실제 건수 Series([], Name: OCRN_DOTW_TUE, dtype: int64)
# 252 . 충청남도경찰청
# [13:15:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: []
# 12월 실제 건수 Series([], Name: OCRN_DOTW_TUE, dtype: int64)
# 253 . 교통과
# 12월 예상 건수: [0]
# 254 . 광주경찰청
# [13:15:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: []
# 12월 실제 건수 Series([], Name: OCRN_DOTW_TUE, dtype: int64)
# 255 . 부산경찰청
# [13:15:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: []
# 12월 실제 건수 Series([], Name: OCRN_DOTW_TUE, dtype: int64)
# 256 . 성주경찰서
# [13:15:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [0.00042853]
# 12월 실제 건수 PLCST_NM
# 성주경찰서    0
# Name: OCRN_DOTW_TUE, dtype: int64
# 257 . 충청북도경찰청
# [13:15:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: []
# 12월 실제 건수 Series([], Name: OCRN_DOTW_TUE, dtype: int64)
# 258 . 경기북부경찰청
# [13:15:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: []
# 12월 실제 건수 Series([], Name: OCRN_DOTW_TUE, dtype: int64)
# 259 . 경기남부경찰청
# [13:15:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [0.09022227]
# 12월 실제 건수 PLCST_NM
# 경기남부경찰청    0
# Name: OCRN_DOTW_TUE, dtype: int64
# 260 . 순창경찰서
# [13:15:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: []
# 12월 실제 건수 Series([], Name: OCRN_DOTW_TUE, dtype: int64)
# 261 . 인천경찰청
# [13:15:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: [0.00059736]
# 12월 실제 건수 PLCST_NM
# 인천경찰청    0
# Name: OCRN_DOTW_TUE, dtype: int64
# 262 . 전라남도경찰청
# 12월 예상 건수: [0]
# 263 . 인천국제공항경찰단
# 12월 예상 건수: [0]
# 264 . 의령경찰서
# [13:15:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: []
# 12월 실제 건수 Series([], Name: OCRN_DOTW_TUE, dtype: int64)
# 265 . 강원경찰청
# [13:15:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: []
# 12월 실제 건수 Series([], Name: OCRN_DOTW_TUE, dtype: int64)
# 266 . 대구경찰청
# [13:15:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: []
# 12월 실제 건수 Series([], Name: OCRN_DOTW_TUE, dtype: int64)
# 267 . 임실경찰서
# [13:15:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: []
# 12월 실제 건수 Series([], Name: OCRN_DOTW_TUE, dtype: int64)
# 268 . 경남경찰청
# [13:15:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: []
# 12월 실제 건수 Series([], Name: OCRN_DOTW_TUE, dtype: int64)
# 269 . 전북경찰청
# 12월 예상 건수: [0]
# 270 . 곡성경찰서
# [13:15:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 12월 예상 건수: []
# 12월 실제 건수 Series([], Name: OCRN_DOTW_TUE, dtype: int64)
# 271 . 대전경찰청
# 12월 예상 건수: [0]
# 272 . 울릉경찰서
# 12월 예상 건수: [0]
# 273 . 영양경찰서
# 12월 예상 건수: [0]
# 274 . 경찰청
# 12월 예상 건수: [0]

# %%
## 반복문 맨 마지막에 쓰인 xg 부스트 모델의 결과가 나오는 것 같음...큰 의미 없을 것으로 보임
xgboost.plot_importance(xgb_model)
plt.rcParams['figure.figsize']=[10,5]
plt.show()

# %%
preds = pd.DataFrame(preds)
preds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 275 entries, 0 to 274
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       231 non-null    float64
# dtypes: float64(1)
# memory usage: 2.3 KB

# %%
preds.isnull().sum()
# Out:
# 0    44
# dtype: int64

# %%
## 결측치 0으로 fillna 로 처리, index와 칼럼명 지정
preds.fillna(0, inplace = True)

preds.rename(columns={0: 'preds'}, inplace=True)
preds
# Out:
#          preds
# 0     7.608289
# 1    10.367917
# 2     6.271647
# 3     6.054859
# 4     3.012378
# ..         ...
# 270   0.000000
# 271   0.000000
# 272   0.000000
# 273   0.000000
# 274   0.000000
#
# [275 rows x 1 columns]

# %%
df.plcst = pd.DataFrame(df.plcst)
df.plcst
# Out:
#             0
# 0     서울중랑경찰서
# 1     서울노원경찰서
# 2    부산해운대경찰서
# 3     울산중부경찰서
# 4     대구성서경찰서
# ..        ...
# 270     곡성경찰서
# 271     대전경찰청
# 272     울릉경찰서
# 273     영양경찰서
# 274       경찰청
#
# [275 rows x 1 columns]

# %%
df2 = df[df['ACPT_YM'] == 202112]
df.rprt = df2[['OCRN_DOTW_TUE','PLCST_NM']]
df.rprt = pd.DataFrame(df.rprt)
df.rprt.set_index('PLCST_NM', inplace = True)
df.rprt
# Out:
#           OCRN_DOTW_TUE
# PLCST_NM
# ETC                  61
# 천안동남경찰서               6
# 화성동탄경찰서               6
# 마산중부경찰서               0
# 울산중부경찰서               2
# ...                 ...
# 인천논현경찰서               7
# 부산중부경찰서               0
# 대전서부경찰서               1
# 함안경찰서                 0
# 상주경찰서                 0
#
# [224 rows x 1 columns]

# %%
result = preds.join(df.plcst)
result.rename(columns={0: 'PLCST_NM'}, inplace=True)

result.set_index('PLCST_NM', inplace = True)
result
# Out:
#               preds
# PLCST_NM
# 서울중랑경찰서    7.608289
# 서울노원경찰서   10.367917
# 부산해운대경찰서   6.271647
# 울산중부경찰서    6.054859
# 대구성서경찰서    3.012378
# ...             ...
# 곡성경찰서      0.000000
# 대전경찰청      0.000000
# 울릉경찰서      0.000000
# 영양경찰서      0.000000
# 경찰청        0.000000
#
# [275 rows x 1 columns]

# %%
result = result.join(df.rprt)
result
# Out:
#               preds  OCRN_DOTW_TUE
# PLCST_NM
# ETC       64.888680           61.0
# 가평경찰서      0.000000            NaN
# 강남경찰서      3.391854            4.0
# 강릉경찰서      3.529470            1.0
# 강원경찰청      0.000000            NaN
# ...             ...            ...
# 화성동탄경찰서    7.776930            6.0
# 화성서부경찰서    3.167421            7.0
# 화순경찰서      0.860318            0.0
# 화천경찰서      0.000000            NaN
# 횡성경찰서      0.982149            0.0
#
# [276 rows x 2 columns]

# %%
result.isna().sum()
# Out:
# preds             0
# OCRN_DOTW_TUE    52
# dtype: int64

# %%
result.fillna(0, inplace = True)
result
# Out:
#               preds  OCRN_DOTW_TUE
# PLCST_NM
# ETC       64.888680           61.0
# 가평경찰서      0.000000            0.0
# 강남경찰서      3.391854            4.0
# 강릉경찰서      3.529470            1.0
# 강원경찰청      0.000000            0.0
# ...             ...            ...
# 화성동탄경찰서    7.776930            6.0
# 화성서부경찰서    3.167421            7.0
# 화순경찰서      0.860318            0.0
# 화천경찰서      0.000000            0.0
# 횡성경찰서      0.982149            0.0
#
# [276 rows x 2 columns]

# %% [markdown]
# # **성능지표결과**

# %%
from sklearn.metrics import  mean_squared_error, mean_absolute_error, r2_score

# %%
sdd = result['OCRN_DOTW_TUE']
pred = result['preds']

# %%
mse = mean_squared_error(sdd, pred)
rmse = mse ** 0.5
r2 = r2_score(sdd, pred)
print("RMSE:",rmse)
print("r2 score:",r2)
# Out:
# RMSE: 2.456509121625898
# r2 score: 0.7493847312236708

# %% [markdown]
# # **관측치와** 예측결과 비교 시각화

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

plt.rc('font', family = 'NanumGothic')
mpl.rc('axes', unicode_minus=False)
print(mpl.rcParams['font.family'])
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20170925-1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 7 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded
# ['NanumGothic']

# %%
plt.figure(figsize=(50, 5))
plt.plot(result, marker = 'o', markersize = 3)
plt.legend(['예측 신고건수','실제 신고건수'], loc='upper left')
plt.xticks(rotation=60)

plt.title("경찰서별 2021년 12월 화요일 신고건수 예측 그래프", size=20)

mpl.rc('axes', unicode_minus=False)
