# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
df1 = pd.read_csv("/content/drive/MyDrive/빅예분3조/Data/prescale/KPU_DATA_MERGE1.csv", encoding='euc-kr')
df2 = pd.read_csv("/content/drive/MyDrive/빅예분3조/Data/prescale/KPU_DATA34.csv", encoding='euc-kr')
df3 = pd.read_csv("/content/drive/MyDrive/빅예분3조/Data/prescale/KPU_DATA19.csv", encoding='euc-kr')

# %%
df2.rename(columns = lambda x: "SCHOOL_" + x, inplace = True)
df3.rename(columns = lambda x: "CHILD_" + x, inplace = True)

# %%
del df1['Unnamed: 0']
del df2['SCHOOL_Unnamed: 0']
del df3['CHILD_Unnamed: 0']

# %%
df2.rename(columns = {'SCHOOL_ACPT_YM':'ACPT_YM','SCHOOL_PLCST_NM':'PLCST_NM'},inplace=True)

# %%
df3.rename(columns = {'CHILD_STRD_YR':'STRD_YR','CHILD_PLCST_NM':'PLCST_NM'},inplace=True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8465 entries, 0 to 8464
# Data columns (total 48 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ACPT_YM                  8465 non-null   int64
#  1   PLCST_NM                 8465 non-null   object
#  2   RPRT_CASCNT_WHOL         8465 non-null   int64
#  3   RPRT_SEX_MALE            8465 non-null   int64
#  4   RPRT_SEX_FMLE            8465 non-null   int64
#  5   RPRT_SEX_UNKWN           8465 non-null   int64
#  6   RPRT_SEX_ETC             8465 non-null   int64
#  7   ACPT_EMERG_TYPE_EMERG    8465 non-null   int64
#  8   ACPT_EMERG_TYPE_IMPRTNC  8465 non-null   int64
#  9   ACPT_EMERG_TYPE_GNRL     8465 non-null   int64
#  10  ACPT_EMERG_TYPE_CVAPP    8465 non-null   int64
#  11  ACPT_EMERG_TYPE_ETC      8465 non-null   int64
#  12  OCRN_DOTW_SNDD           8465 non-null   int64
#  13  OCRN_DOTW_MON            8465 non-null   int64
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5579 entries, 0 to 5578
# Data columns (total 43 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ACPT_YM                         5579 non-null   int64
#  1   PLCST_NM                        5579 non-null   object
#  2   SCHOOL_RPRT_CASCNT_WHOL         5579 non-null   int64
#  3   SCHOOL_RPRT_SEX_MALE            5579 non-null   int64
#  4   SCHOOL_RPRT_SEX_FMLE            5579 non-null   int64
#  5   SCHOOL_RPRT_SEX_UNKWN           5579 non-null   int64
#  6   SCHOOL_RPRT_SEX_ETC             5579 non-null   int64
#  7   SCHOOL_ACPT_EMERG_TYPE_EMERG    5579 non-null   int64
#  8   SCHOOL_ACPT_EMERG_TYPE_IMPRTNC  5579 non-null   int64
#  9   SCHOOL_ACPT_EMERG_TYPE_GNRL     5579 non-null   int64
#  10  SCHOOL_ACPT_EMERG_TYPE_CVAPP    5579 non-null   int64
#  11  SCHOOL_ACPT_EMERG_TYPE_ETC      5579 non-null   int64
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 828 entries, 0 to 827
# Data columns (total 46 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   STRD_YR                        828 non-null    int64
#  1   PLCST_NM                       828 non-null    object
#  2   CHILD_RPRT_CASCNT_WHOL         828 non-null    int64
#  3   CHILD_RPRT_SEX_MALE            828 non-null    int64
#  4   CHILD_RPRT_SEX_FMLE            828 non-null    int64
#  5   CHILD_RPRT_SEX_UNKWN           828 non-null    int64
#  6   CHILD_RPRT_SEX_ETC             828 non-null    int64
#  7   CHILD_ACPT_EMERG_TYPE_EMERG    828 non-null    int64
#  8   CHILD_ACPT_EMERG_TYPE_IMPRTNC  828 non-null    int64
#  9   CHILD_ACPT_EMERG_TYPE_GNRL     828 non-null    int64
#  10  CHILD_ACPT_EMERG_TYPE_CVAPP    828 non-null    int64
#  11  CHILD_ACPT_EMERG_TYPE_ETC      828 non-null    int64
# ...

# %%
df_temp1 = pd.merge(left=df1,right=df2, how='left',on=['ACPT_YM','PLCST_NM'])

# %%
df_temp1.to_csv('/content/drive/MyDrive/빅예분3조/Data/prescale/KPU_DATA_MERGE2.csv')

# %%
len(df_temp1.columns)
# Out:
# 89

# %%
df_temp1 = df_temp1.astype({'ACPT_YM':'str'})

# %%
df_temp1['STRD_YR'] = df_temp1['ACPT_YM'].str.slice(0,4)

# %%
df_temp1['STRD_YR']
# Out:
# 0       2019
# 1       2019
# 2       2019
# 3       2019
# 4       2019
#         ...
# 8462    2021
# 8463    2021
# 8464    2021
# 8465    2021
# 8466    2021
# Name: STRD_YR, Length: 8467, dtype: object

# %%
df3 = df3.astype({'STRD_YR':'str'})

# %%
df_temp2 = pd.merge(left=df_temp1,right=df3, how='left',on=['STRD_YR','PLCST_NM'])

# %%
df_temp2.columns
# Out:
# Index(['ACPT_YM', 'PLCST_NM', 'RPRT_CASCNT_WHOL', 'RPRT_SEX_MALE',
#        'RPRT_SEX_FMLE', 'RPRT_SEX_UNKWN', 'RPRT_SEX_ETC',
#        'ACPT_EMERG_TYPE_EMERG', 'ACPT_EMERG_TYPE_IMPRTNC',
#        'ACPT_EMERG_TYPE_GNRL',
#        ...
#        'CHILD_OCRN_TIZN_14', 'CHILD_OCRN_TIZN_15', 'CHILD_OCRN_TIZN_16',
#        'CHILD_OCRN_TIZN_17', 'CHILD_OCRN_TIZN_18', 'CHILD_OCRN_TIZN_19',
#        'CHILD_OCRN_TIZN_20', 'CHILD_OCRN_TIZN_21', 'CHILD_OCRN_TIZN_22',
#        'CHILD_OCRN_TIZN_23'],
#       dtype='object', length=134)

# %%
df_temp2.to_csv("/content/drive/MyDrive/빅예분3조/Data/prescale/KPU_DATA_MERGE3.csv", encoding='euc-kr')
