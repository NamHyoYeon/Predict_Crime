# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/빅예분3조/Data/prescale/KPU_DATA33.csv", encoding='euc-kr')

# %%
df
# Out:
#       Unnamed: 0  ACPT_YM PLCST_NM  RPRT_CASCNT_WHOL  RPRT_SEX_MALE  \
# 0              0   201901     서울중랑                37             18
# 1              1   201901     서울노원                62             33
# 2              2   201901    부산해운대                37             25
# 3              3   201901     울산중부                56             39
# 4              4   201901     대구성서                24             14
# ...          ...      ...      ...               ...            ...
# 8460        2779   202112     인천논현                39             24
# 8461        2780   202112     부산중부                19              1
# 8462        2781   202112     대전서부                20             15
# 8463        2782   202112       함안                 1              0
# 8464        2783   202112       상주                 1              0
#
#       RPRT_SEX_FMLE  RPRT_SEX_UNKWN  RPRT_SEX_ETC  ACPT_EMERG_TYPE_EMERG  \
# 0                 8              11             0                      0
# ...

# %%
df_plcst_nm = df['PLCST_NM']

# %%
plsct_nm_list = []

# %%
plsct_nm_list = df_plcst_nm.to_list()

# %%
plsct_nm_list = list(set(plsct_nm_list))

# %%
plsct_nm_list
# Out:
# ['양구',
#  '서울남대문',
#  '인천부평',
#  '하남',
#  '옥천',
#  '오산',
#  '남원',
#  '강진',
#  '전남청',
#  '서울구로',
#  '마산동부',
#  '청도',
#  '부산동래',
#  '강원청',
#  '인천연수',
#  '철원',
#  '영광',
#  '김제',
#  '대전동부',
#  '산청',
#  '청주흥덕',
#  '울릉',
#  '경산',
#  '광주광산',
#  '목포',
#  '인천계양',
#  '부산동부',
#  '보령',
#  '충주',
#  '울진',
#  '부산진',
#  '인천국제공항경찰단',
#  '대전청',
#  '안동',
#  '부산강서',
#  '해남',
#  '안성',
#  '부산서부',
#  '장수',
#  '제주서부',
#  '진안',
#  '강원도고성',
#  '동두천',
#  '충남청',
#  '서울중부',
#  '문경',
#  '서울동작',
#  '진천',
#  '태백',
#  '음성',
#  '서산',
#  '제주자치경찰단',
#  '함양',
#  '정읍',
#  '서울강동',
#  '과천',
#  '안산단원',
#  '창원서부',
#  '대구달성',
#  '안양만안',
#  '창녕',
#  '제주동부',
#  '청양',
#  '세종',
#  '고양',
#  '인제',
#  '서울도봉',
#  '대전둔산',
#  '속초',
#  '화천',
#  '당진',
#  '천안동남',
#  '대전유성',
#  '대구남부',
#  '부천원미',
#  '하동',
#  '영주',
#  '안양동안',
#  '광주남부',
#  '금산',
#  '구리',
#  '전북청',
#  '양평',
#  '부산기장',
#  '연천',
#  '울산남부',
#  '청주청원',
#  '남양주',
#  '부산북부',
#  '익산',
#  '부여',
#  '아산',
#  '고창',
#  '원주',
#  '서울서초',
#  '대전대덕',
#  '광명',
#  '일산동부',
#  '창원중부',
#  '평택',
# ...

# %%
# 276개
len(plsct_nm_list)
# Out:
# 276

# %%
plsct_nm_list_map = []

# %%
for i in range(len(plsct_nm_list)):
  plsct_nm_list_map.append(plsct_nm_list[i])

# %%
# 276개
len(plsct_nm_list_map)
# Out:
# 276

# %%
for i in range(len(plsct_nm_list)):
  if plsct_nm_list[i] != 'ETC' and plsct_nm_list[i][-1] !='청' and plsct_nm_list[i][-1] != '과' and plsct_nm_list[i][-1] != '단':
    plsct_nm_list[i] = plsct_nm_list[i]+'경찰서'
  elif plsct_nm_list[i][-1] == '청' and plsct_nm_list[i] != '경찰청' and plsct_nm_list[i] != '산청':
    plsct_nm_list[i] =  plsct_nm_list[i][:-1]+'경찰청'
  elif plsct_nm_list[i] == '산청':
    plsct_nm_list[i] = '산청경찰서'

# %%
plsct_nm_list
# Out:
# ['양구경찰서',
#  '서울남대문경찰서',
#  '인천부평경찰서',
#  '하남경찰서',
#  '옥천경찰서',
#  '오산경찰서',
#  '남원경찰서',
#  '강진경찰서',
#  '전남경찰청',
#  '서울구로경찰서',
#  '마산동부경찰서',
#  '청도경찰서',
#  '부산동래경찰서',
#  '강원경찰청',
#  '인천연수경찰서',
#  '철원경찰서',
#  '영광경찰서',
#  '김제경찰서',
#  '대전동부경찰서',
#  '산청경찰서',
#  '청주흥덕경찰서',
#  '울릉경찰서',
#  '경산경찰서',
#  '광주광산경찰서',
#  '목포경찰서',
#  '인천계양경찰서',
#  '부산동부경찰서',
#  '보령경찰서',
#  '충주경찰서',
#  '울진경찰서',
#  '부산진경찰서',
#  '인천국제공항경찰단',
#  '대전경찰청',
#  '안동경찰서',
#  '부산강서경찰서',
#  '해남경찰서',
#  '안성경찰서',
#  '부산서부경찰서',
#  '장수경찰서',
#  '제주서부경찰서',
#  '진안경찰서',
#  '강원도고성경찰서',
#  '동두천경찰서',
#  '충남경찰청',
#  '서울중부경찰서',
#  '문경경찰서',
#  '서울동작경찰서',
#  '진천경찰서',
#  '태백경찰서',
#  '음성경찰서',
#  '서산경찰서',
#  '제주자치경찰단',
#  '함양경찰서',
#  '정읍경찰서',
#  '서울강동경찰서',
#  '과천경찰서',
#  '안산단원경찰서',
#  '창원서부경찰서',
#  '대구달성경찰서',
#  '안양만안경찰서',
#  '창녕경찰서',
#  '제주동부경찰서',
#  '청양경찰서',
#  '세종경찰서',
#  '고양경찰서',
#  '인제경찰서',
#  '서울도봉경찰서',
#  '대전둔산경찰서',
#  '속초경찰서',
#  '화천경찰서',
#  '당진경찰서',
#  '천안동남경찰서',
#  '대전유성경찰서',
#  '대구남부경찰서',
#  '부천원미경찰서',
#  '하동경찰서',
#  '영주경찰서',
# ...

# %%
for i in range(len(plsct_nm_list)):
  if plsct_nm_list[i] == '울산동부경찰서':
    plsct_nm_list[i] = '동부경찰서'
  elif plsct_nm_list[i] == '서울강남경찰서':
    plsct_nm_list[i] = '강남경찰서'
  elif plsct_nm_list[i] == '경상남도고성경찰서':
    plsct_nm_list[i] = '고성경찰서'
  elif plsct_nm_list[i] == '서울은평경찰서':
    plsct_nm_list[i] = '은평경찰서'
  elif plsct_nm_list[i] == '서울강남경찰서':
    plsct_nm_list[i] = '강남경찰서'
  elif plsct_nm_list[i] == '부산기장경찰서':
    plsct_nm_list[i] = '기장경찰서'
  elif plsct_nm_list[i] == '서울영등포경찰서':
    plsct_nm_list[i] = '영등포경찰서'
  elif plsct_nm_list[i] == '서울금천경찰서':
    plsct_nm_list[i] = '금천경찰서'
  elif plsct_nm_list[i] == '서울서대문경찰서':
    plsct_nm_list[i] = '서대문경찰서'
  elif plsct_nm_list[i] == '서울영등포경찰서':
    plsct_nm_list[i] = '영등포경찰서'
  elif plsct_nm_list[i] == '서울금천경찰서':
    plsct_nm_list[i] = '금천경찰서'
  elif plsct_nm_list[i] == '서울서대문경찰서':
    plsct_nm_list[i] = '서대문경찰서'
  elif plsct_nm_list[i] == '서울영등포경찰서':
    plsct_nm_list[i] = '영등포경찰서'
  elif plsct_nm_list[i] == '서울금천경찰서':
    plsct_nm_list[i] = '금천경찰서'
  elif plsct_nm_list[i] == '서울서대문경찰서':
    plsct_nm_list[i] = '서대문경찰서'
  elif plsct_nm_list[i] == '충남경찰청':
    plsct_nm_list[i] = '충청남도경찰청'
  elif plsct_nm_list[i] == '전남경찰청':
    plsct_nm_list[i] = '전라남도경찰청'
  elif plsct_nm_list[i] == '서울서대문경찰서':
    plsct_nm_list[i] = '서대문경찰서'
  elif plsct_nm_list[i] == '인천연수경찰서':
    plsct_nm_list[i] = '연수경찰서'
  elif plsct_nm_list[i] == '서울성동경찰서':
    plsct_nm_list[i] = '성동경찰서'
  elif plsct_nm_list[i] == '충북경찰청':
    plsct_nm_list[i] = '충청북도경찰청'
  elif plsct_nm_list[i] == '강원도고성경찰서':
    plsct_nm_list[i] = '고성경찰서'

# %%
plsct_nm_list
# Out:
# ['양구경찰서',
#  '서울남대문경찰서',
#  '인천부평경찰서',
#  '하남경찰서',
#  '옥천경찰서',
#  '오산경찰서',
#  '남원경찰서',
#  '강진경찰서',
#  '전라남도경찰청',
#  '서울구로경찰서',
#  '마산동부경찰서',
#  '청도경찰서',
#  '부산동래경찰서',
#  '강원경찰청',
#  '연수경찰서',
#  '철원경찰서',
#  '영광경찰서',
#  '김제경찰서',
#  '대전동부경찰서',
#  '산청경찰서',
#  '청주흥덕경찰서',
#  '울릉경찰서',
#  '경산경찰서',
#  '광주광산경찰서',
#  '목포경찰서',
#  '인천계양경찰서',
#  '부산동부경찰서',
#  '보령경찰서',
#  '충주경찰서',
#  '울진경찰서',
#  '부산진경찰서',
#  '인천국제공항경찰단',
#  '대전경찰청',
#  '안동경찰서',
#  '부산강서경찰서',
#  '해남경찰서',
#  '안성경찰서',
#  '부산서부경찰서',
#  '장수경찰서',
#  '제주서부경찰서',
#  '진안경찰서',
#  '고성경찰서',
#  '동두천경찰서',
#  '충청남도경찰청',
#  '서울중부경찰서',
#  '문경경찰서',
#  '서울동작경찰서',
#  '진천경찰서',
#  '태백경찰서',
#  '음성경찰서',
#  '서산경찰서',
#  '제주자치경찰단',
#  '함양경찰서',
#  '정읍경찰서',
#  '서울강동경찰서',
#  '과천경찰서',
#  '안산단원경찰서',
#  '창원서부경찰서',
#  '대구달성경찰서',
#  '안양만안경찰서',
#  '창녕경찰서',
#  '제주동부경찰서',
#  '청양경찰서',
#  '세종경찰서',
#  '고양경찰서',
#  '인제경찰서',
#  '서울도봉경찰서',
#  '대전둔산경찰서',
#  '속초경찰서',
#  '화천경찰서',
#  '당진경찰서',
#  '천안동남경찰서',
#  '대전유성경찰서',
#  '대구남부경찰서',
#  '부천원미경찰서',
#  '하동경찰서',
#  '영주경찰서',
# ...

# %%
import urllib

# %%
confmKey = 'devU01TX0FVVEgyMDIyMTEyMzIwMzMxODExMzI1NDY=' # 필수 값 승인키

# %%
addr_dic = dict()

# %%
import xml.etree.ElementTree as ET

# %%
def address_api(keyword, count_per_page, current_page, **kwargs): # 필수 값 3가지를 인자로 넘김
	urls = 'http://www.juso.go.kr/addrlink/addrLinkApi.do'
	confmKey = '?' # 필수 값 승인키
	
	params = {
		'keyword': keyword,
		'countPerPage': count_per_page,
		'currentPage': current_page,
		'confmKey': confmKey,
	}
	if kwargs: # 필수 값이 아닌 변수를 params에 추가
		for key, value in kwargs.items():
			params[key] = value
	params_str = urllib.parse.urlencode(params) # dict를 파라미터에 맞는 포맷으로 변경
	
	url = '{}?{}'.format(urls, params_str)
	response = urllib.request.urlopen(url) # Request 객체로 urlopen을 호출하면 요청된 URL에 대한 응답 객체를 반환
	result_xml = response.read().decode('utf-8') # response를 읽고 utf-8로 변형

	return result_xml

# %%
for s in plsct_nm_list:
  result=address_api(s,10,1)
  f = open("/content/drive/MyDrive/빅예분3조/Data/juso/parse.xml",'w')
  f.write(str(result))
  f.close()

  tree = ET.parse("/content/drive/MyDrive/빅예분3조/Data/juso/parse.xml")
  root = tree.getroot()
  juso = root.findall("juso")
  if len(juso)>0:
    road = [x.findtext("roadAddr") for x in juso]
    si = [x.findtext("siNm") for x in juso]
    sgg = [x.findtext("sggNm") for x in juso]
    print(road[0],si[0],sgg[0])
    key1 = 'addr'
    key2 = 'si'
    key3 = 'sgg'
    addr_dic.update({s:{key1:road[0], key2:si[0], key3:sgg[0]}})
# Out:
# 강원도 양구군 양구읍 양남로 1 강원도 양구군
# 서울특별시 중구 서소문로 131-1(서소문동) 서울특별시 중구
# 인천광역시 부평구 길주로 511(청천동) 인천광역시 부평구
# 경기도 하남시 검단로 27(하산곡동) 경기도 하남시
# 충청북도 옥천군 옥천읍 지용로 21 충청북도 옥천군
# 경기도 오산시 동부대로 596(부산동) 경기도 오산시
# 전라북도 남원시 교룡로 185(향교동) 전라북도 남원시
# 전라남도 강진군 강진읍 탐진로 119 전라남도 강진군
# 서울특별시 구로구 가마산로 235(구로동) 서울특별시 구로구
# 경상남도 창원시 마산회원구 합성남17길 56(합성동) 경상남도 창원시 마산회원구
# 경상북도 청도군 청도읍 새마을로 1362 경상북도 청도군
# 부산광역시 동래구 명륜로 70(수안동) 부산광역시 동래구
# 강원도 춘천시 동내면 세실로 49 강원도 춘천시
# 인천광역시 연수구 원인재로 138(연수동) 인천광역시 연수구
# 강원도 철원군 갈말읍 삼부연로 35 강원도 철원군
# 전라남도 영광군 영광읍 중앙로 211 전라남도 영광군
# 전라북도 김제시 두월로 194(신풍동) 전라북도 김제시
# 대전광역시 동구 충무로 222(인동) 대전광역시 동구
# 경상남도 산청군 산청읍 중앙로 1 경상남도 산청군
# 충청북도 청주시 흥덕구 월명로236번길 15(봉명동) 충청북도 청주시 흥덕구
# 경상북도 울릉군 울릉읍 도동2길 62 경상북도 울릉군
# 경상북도 경산시 원효로 68(계양동) 경상북도 경산시
# 광주광역시 광산구 어등대로 551(운수동) 광주광역시 광산구
# 전라남도 목포시 동명로 124(용당동) 전라남도 목포시
# 인천광역시 계양구 계산새로 68(계산동) 인천광역시 계양구
# 부산광역시 동구 망양로 811(수정동) 부산광역시 동구
# 충청남도 보령시 대천로 33(대천동) 충청남도 보령시
# 충청북도 충주시 예성로 218(교현동) 충청북도 충주시
# 경상북도 울진군 금강송면 불영계곡로 105 경상북도 울진군
# ...

# %%
for s in plsct_nm_list:
    if s not in list(addr_dic.keys()):
        print(s)
# Out:
# 전라남도경찰청
# 인천국제공항경찰단
# 제주자치경찰단
# 청주청원경찰서
# 공주경찰서
# 경비교통과
# 인천논현경찰서
# 경기남부경찰청
# 곡성경찰서

# %%
addr_dic['제주자치경찰단'] = {'addr':'제주도 제주시 기자길 7', 'si':'제주도', 'sgg':'제주시'}
addr_dic['공주경찰서']  = {'addr':'충청남도 공주시 백제문화로 2148-15', 'si':'충청남도', 'sgg':'공주시'}
addr_dic['인천논현경찰서'] = {'addr':'인천광역시 남동구 논현고잔로 239', 'si':'인천광역시', 'sgg':'남동구'}
addr_dic['청주청원경찰서'] = {'addr':'충청북도 청주시 청원구 항군로 60', 'si':'충청북도', 'sgg':'청주시'}
addr_dic['곡성경찰서']  = {'addr':'전라남도 곡성군 곡성읍 중앙로 161', 'si':'전라남도', 'sgg':'곡성군'}
addr_dic['경기남부경찰청'] = {'addr':'경기도 수원시 장안구 창룡대로 223', 'si':'경기도', 'sgg':'수원시'}
addr_dic['경비교통과'] = {'addr':'서울특별시 종로구 사직로 8길 31', 'si':'서울특별시', 'sgg':'종로구'}
addr_dic['인천국제공항경찰단'] = {'addr':'인천광역시 중구 공항로 272', 'si':'인천광역시', 'sgg':'중구'}
addr_dic['전라남도경찰청'] = {'addr':'전라남도 무안군 삼항읍 후광대로 359번길 28', 'si':'전라남도', 'sgg':'무안군'}

# %%
import json
import requests

# %%
"274d1bacd4c26f9e457ea55abbdd6cd5"

# %%
def addr_to_lat_lon(addr):
    url = 'https://dapi.kakao.com/v2/local/search/address.json?query={address}'.format(address=addr)
    api_key = "?"
    headers = {"Authorization": "KakaoAK " + api_key}
    result = json.loads(str(requests.get(url, headers=headers).text))
    match_first = result['documents'][0]['address']
    return float(match_first['x']), float(match_first['y'])

# %%
print(addr_to_lat_lon('서울특별시 종로구 사직로8길 31'))
# Out:
# (126.971979688446, 37.5749462708923)

# %%
addr_dic
# Out:
# {'양구경찰서': {'addr': '강원도 양구군 양구읍 양남로 1', 'si': '강원도', 'sgg': '양구군'},
#  '서울남대문경찰서': {'addr': '서울특별시 중구 서소문로 131-1(서소문동)', 'si': '서울특별시', 'sgg': '중구'},
#  '인천부평경찰서': {'addr': '인천광역시 부평구 길주로 511(청천동)', 'si': '인천광역시', 'sgg': '부평구'},
#  '하남경찰서': {'addr': '경기도 하남시 검단로 27(하산곡동)', 'si': '경기도', 'sgg': '하남시'},
#  '옥천경찰서': {'addr': '충청북도 옥천군 옥천읍 지용로 21', 'si': '충청북도', 'sgg': '옥천군'},
#  '오산경찰서': {'addr': '경기도 오산시 동부대로 596(부산동)', 'si': '경기도', 'sgg': '오산시'},
#  '남원경찰서': {'addr': '전라북도 남원시 교룡로 185(향교동)', 'si': '전라북도', 'sgg': '남원시'},
#  '강진경찰서': {'addr': '전라남도 강진군 강진읍 탐진로 119', 'si': '전라남도', 'sgg': '강진군'},
#  '서울구로경찰서': {'addr': '서울특별시 구로구 가마산로 235(구로동)', 'si': '서울특별시', 'sgg': '구로구'},
#  '마산동부경찰서': {'addr': '경상남도 창원시 마산회원구 합성남17길 56(합성동)',
#   'si': '경상남도',
#   'sgg': '창원시 마산회원구'},
#  '청도경찰서': {'addr': '경상북도 청도군 청도읍 새마을로 1362', 'si': '경상북도', 'sgg': '청도군'},
#  '부산동래경찰서': {'addr': '부산광역시 동래구 명륜로 70(수안동)', 'si': '부산광역시', 'sgg': '동래구'},
# ...

# %%
for i in addr_dic.keys():
    lat, lon = addr_to_lat_lon(addr_dic[i]['addr'])
    print(lat,lon)
    key4='lat'
    key5='lon'
    addr_dic[i].update({key4:lat, key5:lon})
# Out:
# 127.99141342403 38.1052212161836
# 126.975466927468 37.5638265102548
# 126.719342962375 37.5078526389529
# 127.224643080043 37.5226716618107
# 127.578184620922 36.3122813023677
# 127.082245675536 37.1536368556184
# 127.372338822331 35.4136484090809
# 126.767922814633 34.6423140183008
# 126.887014988407 37.4945320625106
# 128.590222252696 35.2381219356388
# 128.750222251971 35.6537344001594
# 129.084649682124 35.2006444533198
# 127.757292578182 37.8618941014695
# 126.681375263397 37.4101684311396
# 127.311240662533 38.1460783943116
# 126.512482385445 35.2781578790678
# 126.901989026293 35.7924467402045
# 127.440828341064 36.3217220616265
# 127.874442004512 35.4164427939169
# 127.45496461858 36.6565677318005
# 130.905851668763 37.4843091297771
# 128.744993163479 35.8221266190558
# 126.782766508945 35.152794673652
# 126.397126207827 34.7985102087847
# 126.735747338651 37.5375960906488
# 129.043526376927 35.1348638870622
# 126.597223223581 36.3513011910118
# ...

# %%
for s in plsct_nm_list:
    if s not in list(addr_dic.keys()):
        print(s)

# %%
addr_dic
# Out:
# {'양구경찰서': {'addr': '강원도 양구군 양구읍 양남로 1',
#   'si': '강원도',
#   'sgg': '양구군',
#   'lat': 127.99141342403,
#   'lon': 38.1052212161836},
#  '서울남대문경찰서': {'addr': '서울특별시 중구 서소문로 131-1(서소문동)',
#   'si': '서울특별시',
#   'sgg': '중구',
#   'lat': 126.975466927468,
#   'lon': 37.5638265102548},
#  '인천부평경찰서': {'addr': '인천광역시 부평구 길주로 511(청천동)',
#   'si': '인천광역시',
#   'sgg': '부평구',
#   'lat': 126.719342962375,
#   'lon': 37.5078526389529},
#  '하남경찰서': {'addr': '경기도 하남시 검단로 27(하산곡동)',
#   'si': '경기도',
#   'sgg': '하남시',
#   'lat': 127.224643080043,
#   'lon': 37.5226716618107},
#  '옥천경찰서': {'addr': '충청북도 옥천군 옥천읍 지용로 21',
#   'si': '충청북도',
#   'sgg': '옥천군',
#   'lat': 127.578184620922,
#   'lon': 36.3122813023677},
#  '오산경찰서': {'addr': '경기도 오산시 동부대로 596(부산동)',
#   'si': '경기도',
#   'sgg': '오산시',
#   'lat': 127.082245675536,
#   'lon': 37.1536368556184},
#  '남원경찰서': {'addr': '전라북도 남원시 교룡로 185(향교동)',
#   'si': '전라북도',
#   'sgg': '남원시',
#   'lat': 127.372338822331,
#   'lon': 35.4136484090809},
# ...

# %%
# 경기남부경찰청 (127.033670481624, 37.2946898810341)
# 경비교통과 (126.971979688446, 37.5749462708923)
# 인천국제공항경찰단 (126.427699293474, 37.458350712273)
addr_dic['경기남부경찰청'].update({'lat':'127.033670481624', 'lon':'37.2946898810341'})
addr_dic['경비교통과'].update({'lat':'126.971979688446', 'lon':'37.5749462708923'})
addr_dic['인천국제공항경찰단'].update({'lat':'126.427699293474', 'lon':'37.458350712273'})

# %%
# f = open("/content/drive/MyDrive/빅예분3조/Data/juso/addr.txt",'w')
# f.write(str(addr_dic))
# f.close()

# %%
df
# Out:
#       Unnamed: 0  ACPT_YM PLCST_NM  RPRT_CASCNT_WHOL  RPRT_SEX_MALE  \
# 0              0   201901     서울중랑                37             18
# 1              1   201901     서울노원                62             33
# 2              2   201901    부산해운대                37             25
# 3              3   201901     울산중부                56             39
# 4              4   201901     대구성서                24             14
# ...          ...      ...      ...               ...            ...
# 8460        2779   202112     인천논현                39             24
# 8461        2780   202112     부산중부                19              1
# 8462        2781   202112     대전서부                20             15
# 8463        2782   202112       함안                 1              0
# 8464        2783   202112       상주                 1              0
#
#       RPRT_SEX_FMLE  RPRT_SEX_UNKWN  RPRT_SEX_ETC  ACPT_EMERG_TYPE_EMERG  \
# 0                 8              11             0                      0
# ...

# %%
del df['Unnamed: 0']
df
# Out:
#       ACPT_YM PLCST_NM  RPRT_CASCNT_WHOL  RPRT_SEX_MALE  RPRT_SEX_FMLE  \
# 0      201901     서울중랑                37             18              8
# 1      201901     서울노원                62             33             19
# 2      201901    부산해운대                37             25              6
# 3      201901     울산중부                56             39             11
# 4      201901     대구성서                24             14              4
# ...       ...      ...               ...            ...            ...
# 8460   202112     인천논현                39             24              8
# 8461   202112     부산중부                19              1              2
# 8462   202112     대전서부                20             15              3
# 8463   202112       함안                 1              0              1
# 8464   202112       상주                 1              0              1
#
#       RPRT_SEX_UNKWN  RPRT_SEX_ETC  ACPT_EMERG_TYPE_EMERG  \
# ...

# %%
len(plsct_nm_list_map)
# Out:
# 276

# %%
len(plsct_nm_list)
# Out:
# 276

# %%
# 경찰서 값 바꿔주기
for i in range(len(plsct_nm_list_map)):
  df.loc[df['PLCST_NM']==plsct_nm_list_map[i],('PLCST_NM')] = plsct_nm_list[i]

# %%
df
# Out:
#       ACPT_YM  PLCST_NM  RPRT_CASCNT_WHOL  RPRT_SEX_MALE  RPRT_SEX_FMLE  \
# 0      201901   서울중랑경찰서                37             18              8
# 1      201901   서울노원경찰서                62             33             19
# 2      201901  부산해운대경찰서                37             25              6
# 3      201901   울산중부경찰서                56             39             11
# 4      201901   대구성서경찰서                24             14              4
# ...       ...       ...               ...            ...            ...
# 8460   202112   인천논현경찰서                39             24              8
# 8461   202112   부산중부경찰서                19              1              2
# 8462   202112   대전서부경찰서                20             15              3
# 8463   202112     함안경찰서                 1              0              1
# 8464   202112     상주경찰서                 1              0              1
#
#       RPRT_SEX_UNKWN  RPRT_SEX_ETC  ACPT_EMERG_TYPE_EMERG  \
# ...

# %%
# 경찰서 주소값
for i in range(len(plsct_nm_list)):
  df.loc[df['PLCST_NM']==plsct_nm_list[i],('ADDR')] = addr_dic[plsct_nm_list[i]]['addr']

# %%
# 경찰서 시, 군구
for i in range(len(plsct_nm_list)):
  df.loc[df['PLCST_NM']==plsct_nm_list[i],('SI')] = addr_dic[plsct_nm_list[i]]['si']
  df.loc[df['PLCST_NM']==plsct_nm_list[i],('SGG')] = addr_dic[plsct_nm_list[i]]['sgg']

# %%
df
# Out:
#       ACPT_YM  PLCST_NM  RPRT_CASCNT_WHOL  RPRT_SEX_MALE  RPRT_SEX_FMLE  \
# 0      201901   서울중랑경찰서                37             18              8
# 1      201901   서울노원경찰서                62             33             19
# 2      201901  부산해운대경찰서                37             25              6
# 3      201901   울산중부경찰서                56             39             11
# 4      201901   대구성서경찰서                24             14              4
# ...       ...       ...               ...            ...            ...
# 8460   202112   인천논현경찰서                39             24              8
# 8461   202112   부산중부경찰서                19              1              2
# 8462   202112   대전서부경찰서                20             15              3
# 8463   202112     함안경찰서                 1              0              1
# 8464   202112     상주경찰서                 1              0              1
#
#       RPRT_SEX_UNKWN  RPRT_SEX_ETC  ACPT_EMERG_TYPE_EMERG  \
# ...

# %%
# 경찰서 경도, 위도
for i in range(len(plsct_nm_list)):
  if 'lat' in list(addr_dic[plsct_nm_list[i]].keys()): ## 위도 경도 없는 것도 존재
    print("inin")
    df.loc[df['PLCST_NM']==plsct_nm_list[i],('LON')] = addr_dic[plsct_nm_list[i]]['lon']
    df.loc[df['PLCST_NM']==plsct_nm_list[i],('LAT')] = addr_dic[plsct_nm_list[i]]['lat']
# Out:
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# inin
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8465 entries, 0 to 8464
# Data columns (total 48 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ACPT_YM                  8465 non-null   int64
#  1   PLCST_NM                 8465 non-null   object
#  2   RPRT_CASCNT_WHOL         8465 non-null   int64
#  3   RPRT_SEX_MALE            8465 non-null   int64
#  4   RPRT_SEX_FMLE            8465 non-null   int64
#  5   RPRT_SEX_UNKWN           8465 non-null   int64
#  6   RPRT_SEX_ETC             8465 non-null   int64
#  7   ACPT_EMERG_TYPE_EMERG    8465 non-null   int64
#  8   ACPT_EMERG_TYPE_IMPRTNC  8465 non-null   int64
#  9   ACPT_EMERG_TYPE_GNRL     8465 non-null   int64
#  10  ACPT_EMERG_TYPE_CVAPP    8465 non-null   int64
#  11  ACPT_EMERG_TYPE_ETC      8465 non-null   int64
#  12  OCRN_DOTW_SNDD           8465 non-null   int64
#  13  OCRN_DOTW_MON            8465 non-null   int64
# ...

# %%
df.to_csv("/content/drive/MyDrive/빅예분3조/Data/prescale\KPU_DATA_MERGE1.csv", encoding='euc-kr')
